# %% [markdown]
# # Prepare Basin Averaged Forcing for NextGen CFE Model (New York City)
#
# **Author:** [Javed Ali](https://www.javedali.net/) (University of Central Florida)
#
# **Date:** 06.26.2023
#
# **Description**:
#
# The purpose of this Jupyter Notebook is to prepare basin averaged forcing input from for the [NOAA Next Generation (NextGen) Water Resource Modeling Framework](https://github.com/NOAA-OWP/ngen) from AORC **v1.0** kerchunk header files.
#
# **Link to data**:
# - Original: https://noaa-nwm-retrospective-2-1-pds.s3.amazonaws.com/index.html#forcing/
# - Kerchunk: https://ciroh-nwm-zarr-retrospective-data-copy.s3.amazonaws.com/index.html#noaa-nwm-retrospective-2-1-zarr-pds/
#
# **Software Requirements**:
#
# The software and operating system versions used to develop this notebook are listed below. To avoid encountering issues related to version conflicts among Python packages, we recommend creating a new environment variable and installing the required packages specifically for this notebook.
#
# Tested on: Windows (`python: 3.9.16`)
#
# > dask: 2023.5.1 \
#   numpy: 1.24.3 \
#     xarray: 2023.5.0 \
#     pyproj: 3.5.0 \
#     pandas: 2.0.2 \
#     requests: 2.31.0 \
#     geopandas: 0.13.2 \
#     matplotlib: 3.7.1 \
#     zarr: 2.15.0 \
#     fsspec: 2023.6.0 \
#     s3fs: 2023.6.0 \
#     kerchunk:0.1.2
#
# <div class="alert alert-block alert-info">
# <b>Acknowledgement:</b> This notebook is adapted from the code developed by CAUHSI team Tony Castronova and Irene Garousi-Nejad.
# </div>
#
# ---

# %%
# install rioxarray and geocube
# !pip install rioxarray -q
# !pip install geocube -q

# %%
# data collection and manipulation
import re
import dask
import numpy
import xarray
import pandas as pd
import pandas
import requests
import zarr
import fsspec
from pyproj import Transformer
from s3fs import S3FileSystem
from kerchunk.combine import MultiZarrToZarr

# progress bar
from tqdm.notebook import tqdm

# geospatial analysis
import pyproj
import geopandas
import rioxarray
from geocube.api.core import make_geocube

# data viz
from matplotlib import colors
import matplotlib.pyplot as plt

# distributed computing
import xml.etree.ElementTree as ET
from dask.distributed import Client
from dask.distributed import progress

# system
import os

# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %reload_ext watermark

# %%
# %watermark
# Out:
# Last updated: 2023-07-16T23:56:11.843085+00:00
#
# Python implementation: CPython
# Python version       : 3.9.16
# IPython version      : 8.14.0
#
# Compiler    : GCC 11.3.0
# OS          : Linux
# Release     : 5.15.107+
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 14
# Architecture: 64bit

# %% [markdown]
# Initiate the Dask client. This will enable us to parallelize our computations.

# %%
# use a try accept loop so we only instantiate the client
# if it doesn't already exist.
try:
    print(client.dashboard_link)
except:    
    # The client should be customized to your workstation resources.
    client = Client(n_workers=6, memory_limit='10GB') # per worker 
    print(client.dashboard_link)
# Out:
# proxy/8787/status

# %% [markdown]
# ---

# %% [markdown]
# ## Load Forcing Data into Memory
#
# In this notebook we'll be working with AORC v1.0 meteorological forcing. These data are publicly available for the entire CONUS, spanning from 1980 to 2020. Kerchunk header files have been created by the Alabama Water Institute team and this is an ongoing project. Please note that this jupyter notebook works for data within 2007-2019, but it cannot work with data prior to 2006.

# %%
# define the selected watershed boundary 
wb_id = 'wb-698891'
# wb_ids_list = ['wb-694856', 'wb-694725', 'wb-694855', 'wb-694724', 'wb-694854', 'wb-694723', 'wb-698891', 'wb-694722']

# define the year of interest
year=2017

# %%
bucket = 's3://ciroh-nwm-zarr-retrospective-data-copy/noaa-nwm-retrospective-2-1-zarr-pds/forcing/'

# create an instace of the S3FileSystem class from s3fs
s3 = S3FileSystem(anon=True)
files = s3.ls(f'{bucket}{year}')  

new_files = []
for f in files:
    parts = f.split('/')
    parts[0] += '.s3.amazonaws.com'
    parts.insert(0, 'https:/')
    new_name = '/'.join(parts)
    new_files.append(new_name)

# %%
print(len(new_files))
new_files[0]
# Out:
# 8760
# 'https://ciroh-nwm-zarr-retrospective-data-copy.s3.amazonaws.com/noaa-nwm-retrospective-2-1-zarr-pds/forcing/2017/2017010100.LDASIN_DOMAIN1.json'

# %% [markdown]
# Considering the memory limitations, it is necessary to choose a smaller subset of the dataset. Afterwards, we can utilize the `MultiZarrToZarr` function from the kerchunk library to merge the individual header files and generate a single kerchunk file.

# %%
print(new_files[7150])
print(new_files[7350])
# Out:
# https://ciroh-nwm-zarr-retrospective-data-copy.s3.amazonaws.com/noaa-nwm-retrospective-2-1-zarr-pds/forcing/2017/2017102522.LDASIN_DOMAIN1.json
# https://ciroh-nwm-zarr-retrospective-data-copy.s3.amazonaws.com/noaa-nwm-retrospective-2-1-zarr-pds/forcing/2017/2017110306.LDASIN_DOMAIN1.json

# %% [markdown]
# > Tropical Storm Philippe | 26-Oct-2017 to 1-Nov-2017

# %%
# %%time
json_list = new_files[7150:7350] # new_files[start_index:end_index] 

mzz = MultiZarrToZarr(json_list,
    remote_protocol='s3',
    remote_options={'anon':True},
    concat_dims=['valid_time'])

d = mzz.translate()

backend_args = {"consolidated": False, "storage_options": {"fo": d}, "consolidated": False}

ds = xarray.open_dataset("reference://", engine="zarr", backend_kwargs=backend_args)

print(f'Available time range: {ds.Times.min().values.item()} -> {ds.Times.max().values.item()}')
# Out:
# Available time range: b'2017-10-25_22:00:00' -> b'2017-11-03_05:00:00'
# CPU times: user 2.59 s, sys: 478 ms, total: 3.06 s
# Wall time: 3.14 s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (valid_time: 200, Time: 1, south_north: 3840, west_east: 4608)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 2017-10-25T22:00:00 ... 2017-11-0...
# Dimensions without coordinates: Time, south_north, west_east
# Data variables:
#     LWDOWN      (valid_time, Time, south_north, west_east) float32 ...
#     PSFC        (valid_time, Time, south_north, west_east) float32 ...
#     Q2D         (valid_time, Time, south_north, west_east) float32 ...
#     RAINRATE    (valid_time, Time, south_north, west_east) float32 ...
#     SWDOWN      (valid_time, Time, south_north, west_east) float32 ...
#     T2D         (valid_time, Time, south_north, west_east) float32 ...
#     Times       (valid_time) |S20 b'2017-10-25_22:00:00' ... b'2017-11-03_05:...
#     U2D         (valid_time, Time, south_north, west_east) float32 ...
#     V2D         (valid_time, Time, south_north, west_east) float32 ...

# %%
ds.valid_time
# Out:
# <xarray.DataArray 'valid_time' (valid_time: 200)>
# array(['2017-10-25T22:00:00.000000000', '2017-10-25T23:00:00.000000000',
#        '2017-10-26T00:00:00.000000000', '2017-10-26T01:00:00.000000000',
#        '2017-10-26T02:00:00.000000000', '2017-10-26T03:00:00.000000000',
#        '2017-10-26T04:00:00.000000000', '2017-10-26T05:00:00.000000000',
#        '2017-10-26T06:00:00.000000000', '2017-10-26T07:00:00.000000000',
#        '2017-10-26T08:00:00.000000000', '2017-10-26T09:00:00.000000000',
#        '2017-10-26T10:00:00.000000000', '2017-10-26T11:00:00.000000000',
#        '2017-10-26T12:00:00.000000000', '2017-10-26T13:00:00.000000000',
#        '2017-10-26T14:00:00.000000000', '2017-10-26T15:00:00.000000000',
#        '2017-10-26T16:00:00.000000000', '2017-10-26T17:00:00.000000000',
#        '2017-10-26T18:00:00.000000000', '2017-10-26T19:00:00.000000000',
#        '2017-10-26T20:00:00.000000000', '2017-10-26T21:00:00.000000000',
#        '2017-10-26T22:00:00.000000000', '2017-10-26T23:00:00.000000000',
#        '2017-10-27T00:00:00.000000000', '2017-10-27T01:00:00.000000000',
#        '2017-10-27T02:00:00.000000000', '2017-10-27T03:00:00.000000000',
#        '2017-10-27T04:00:00.000000000', '2017-10-27T05:00:00.000000000',
#        '2017-10-27T06:00:00.000000000', '2017-10-27T07:00:00.000000000',
#        '2017-10-27T08:00:00.000000000', '2017-10-27T09:00:00.000000000',
#        '2017-10-27T10:00:00.000000000', '2017-10-27T11:00:00.000000000',
#        '2017-10-27T12:00:00.000000000', '2017-10-27T13:00:00.000000000',
#        '2017-10-27T14:00:00.000000000', '2017-10-27T15:00:00.000000000',
#        '2017-10-27T16:00:00.000000000', '2017-10-27T17:00:00.000000000',
#        '2017-10-27T18:00:00.000000000', '2017-10-27T19:00:00.000000000',
#        '2017-10-27T20:00:00.000000000', '2017-10-27T21:00:00.000000000',
#        '2017-10-27T22:00:00.000000000', '2017-10-27T23:00:00.000000000',
#        '2017-10-28T00:00:00.000000000', '2017-10-28T01:00:00.000000000',
#        '2017-10-28T02:00:00.000000000', '2017-10-28T03:00:00.000000000',
#        '2017-10-28T04:00:00.000000000', '2017-10-28T05:00:00.000000000',
#        '2017-10-28T06:00:00.000000000', '2017-10-28T07:00:00.000000000',
#        '2017-10-28T08:00:00.000000000', '2017-10-28T09:00:00.000000000',
#        '2017-10-28T10:00:00.000000000', '2017-10-28T11:00:00.000000000',
#        '2017-10-28T12:00:00.000000000', '2017-10-28T13:00:00.000000000',
#        '2017-10-28T14:00:00.000000000', '2017-10-28T15:00:00.000000000',
#        '2017-10-28T16:00:00.000000000', '2017-10-28T17:00:00.000000000',
#        '2017-10-28T18:00:00.000000000', '2017-10-28T19:00:00.000000000',
#        '2017-10-28T20:00:00.000000000', '2017-10-28T21:00:00.000000000',
#        '2017-10-28T22:00:00.000000000', '2017-10-28T23:00:00.000000000',
#        '2017-10-29T00:00:00.000000000', '2017-10-29T01:00:00.000000000',
#        '2017-10-29T02:00:00.000000000', '2017-10-29T03:00:00.000000000',
#        '2017-10-29T04:00:00.000000000', '2017-10-29T05:00:00.000000000',
#        '2017-10-29T06:00:00.000000000', '2017-10-29T07:00:00.000000000',
#        '2017-10-29T08:00:00.000000000', '2017-10-29T09:00:00.000000000',
#        '2017-10-29T10:00:00.000000000', '2017-10-29T11:00:00.000000000',
#        '2017-10-29T12:00:00.000000000', '2017-10-29T13:00:00.000000000',
#        '2017-10-29T14:00:00.000000000', '2017-10-29T15:00:00.000000000',
#        '2017-10-29T16:00:00.000000000', '2017-10-29T17:00:00.000000000',
#        '2017-10-29T18:00:00.000000000', '2017-10-29T19:00:00.000000000',
#        '2017-10-29T20:00:00.000000000', '2017-10-29T21:00:00.000000000',
#        '2017-10-29T22:00:00.000000000', '2017-10-29T23:00:00.000000000',
#        '2017-10-30T00:00:00.000000000', '2017-10-30T01:00:00.000000000',
#        '2017-10-30T02:00:00.000000000', '2017-10-30T03:00:00.000000000',
#        '2017-10-30T04:00:00.000000000', '2017-10-30T05:00:00.000000000',
#        '2017-10-30T06:00:00.000000000', '2017-10-30T07:00:00.000000000',
#        '2017-10-30T08:00:00.000000000', '2017-10-30T09:00:00.000000000',
#        '2017-10-30T10:00:00.000000000', '2017-10-30T11:00:00.000000000',
#        '2017-10-30T12:00:00.000000000', '2017-10-30T13:00:00.000000000',
#        '2017-10-30T14:00:00.000000000', '2017-10-30T15:00:00.000000000',
#        '2017-10-30T16:00:00.000000000', '2017-10-30T17:00:00.000000000',
#        '2017-10-30T18:00:00.000000000', '2017-10-30T19:00:00.000000000',
#        '2017-10-30T20:00:00.000000000', '2017-10-30T21:00:00.000000000',
#        '2017-10-30T22:00:00.000000000', '2017-10-30T23:00:00.000000000',
#        '2017-10-31T00:00:00.000000000', '2017-10-31T01:00:00.000000000',
#        '2017-10-31T02:00:00.000000000', '2017-10-31T03:00:00.000000000',
#        '2017-10-31T04:00:00.000000000', '2017-10-31T05:00:00.000000000',
#        '2017-10-31T06:00:00.000000000', '2017-10-31T07:00:00.000000000',
#        '2017-10-31T08:00:00.000000000', '2017-10-31T09:00:00.000000000',
#        '2017-10-31T10:00:00.000000000', '2017-10-31T11:00:00.000000000',
#        '2017-10-31T12:00:00.000000000', '2017-10-31T13:00:00.000000000',
#        '2017-10-31T14:00:00.000000000', '2017-10-31T15:00:00.000000000',
#        '2017-10-31T16:00:00.000000000', '2017-10-31T17:00:00.000000000',
#        '2017-10-31T18:00:00.000000000', '2017-10-31T19:00:00.000000000',
#        '2017-10-31T20:00:00.000000000', '2017-10-31T21:00:00.000000000',
#        '2017-10-31T22:00:00.000000000', '2017-10-31T23:00:00.000000000',
#        '2017-11-01T00:00:00.000000000', '2017-11-01T01:00:00.000000000',
#        '2017-11-01T02:00:00.000000000', '2017-11-01T03:00:00.000000000',
#        '2017-11-01T04:00:00.000000000', '2017-11-01T05:00:00.000000000',
#        '2017-11-01T06:00:00.000000000', '2017-11-01T07:00:00.000000000',
#        '2017-11-01T08:00:00.000000000', '2017-11-01T09:00:00.000000000',
#        '2017-11-01T10:00:00.000000000', '2017-11-01T11:00:00.000000000',
#        '2017-11-01T12:00:00.000000000', '2017-11-01T13:00:00.000000000',
#        '2017-11-01T14:00:00.000000000', '2017-11-01T15:00:00.000000000',
#        '2017-11-01T16:00:00.000000000', '2017-11-01T17:00:00.000000000',
#        '2017-11-01T18:00:00.000000000', '2017-11-01T19:00:00.000000000',
#        '2017-11-01T20:00:00.000000000', '2017-11-01T21:00:00.000000000',
#        '2017-11-01T22:00:00.000000000', '2017-11-01T23:00:00.000000000',
#        '2017-11-02T00:00:00.000000000', '2017-11-02T01:00:00.000000000',
#        '2017-11-02T02:00:00.000000000', '2017-11-02T03:00:00.000000000',
#        '2017-11-02T04:00:00.000000000', '2017-11-02T05:00:00.000000000',
#        '2017-11-02T06:00:00.000000000', '2017-11-02T07:00:00.000000000',
#        '2017-11-02T08:00:00.000000000', '2017-11-02T09:00:00.000000000',
#        '2017-11-02T10:00:00.000000000', '2017-11-02T11:00:00.000000000',
#        '2017-11-02T12:00:00.000000000', '2017-11-02T13:00:00.000000000',
#        '2017-11-02T14:00:00.000000000', '2017-11-02T15:00:00.000000000',
#        '2017-11-02T16:00:00.000000000', '2017-11-02T17:00:00.000000000',
#        '2017-11-02T18:00:00.000000000', '2017-11-02T19:00:00.000000000',
#        '2017-11-02T20:00:00.000000000', '2017-11-02T21:00:00.000000000',
#        '2017-11-02T22:00:00.000000000', '2017-11-02T23:00:00.000000000',
#        '2017-11-03T00:00:00.000000000', '2017-11-03T01:00:00.000000000',
#        '2017-11-03T02:00:00.000000000', '2017-11-03T03:00:00.000000000',
#        '2017-11-03T04:00:00.000000000', '2017-11-03T05:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 2017-10-25T22:00:00 ... 2017-11-0...

# %% [markdown]
# Use SQUEEZE function to remove the Time dimension that has a size of 1 .

# %%
ds = ds.squeeze(dim='Time')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:     (valid_time: 200, south_north: 3840, west_east: 4608)
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 2017-10-25T22:00:00 ... 2017-11-0...
# Dimensions without coordinates: south_north, west_east
# Data variables:
#     LWDOWN      (valid_time, south_north, west_east) float32 ...
#     PSFC        (valid_time, south_north, west_east) float32 ...
#     Q2D         (valid_time, south_north, west_east) float32 ...
#     RAINRATE    (valid_time, south_north, west_east) float32 ...
#     SWDOWN      (valid_time, south_north, west_east) float32 ...
#     T2D         (valid_time, south_north, west_east) float32 ...
#     Times       (valid_time) |S20 b'2017-10-25_22:00:00' ... b'2017-11-03_05:...
#     U2D         (valid_time, south_north, west_east) float32 ...
#     V2D         (valid_time, south_north, west_east) float32 ...

# %% [markdown]
# ## Add spatial metadata to the dataset

# %% [markdown]
# Load the metadata dataset using `xarray` and add spatial metadata to it.

# %%
ds_meta = xarray.open_dataset('http://thredds.hydroshare.org/thredds/dodsC/hydroshare/resources/2a8a3566e1c84b8eb3871f30841a3855/data/contents/WRF_Hydro_NWM_geospatial_data_template_land_GIS.nc')

leny = len(ds_meta.y)
x = ds_meta.x.values
y = ds_meta.y.values

ds = ds.rename({'valid_time': 'time', 'south_north':'y', 'west_east':'x'})
#ds.rename_dims(south_north='y', west_east='x', valid_time='time')

X, Y = numpy.meshgrid(x, y)

# define the input crs
wrf_proj = pyproj.Proj(proj='lcc',
                       lat_1=30.,
                       lat_2=60., 
                       lat_0=40.0000076293945, lon_0=-97., # Center point
                       a=6370000, b=6370000)

# define the output crs
wgs_proj = pyproj.Proj(proj='latlong', datum='WGS84')

# transform X, Y into Lat, Lon
transformer = pyproj.Transformer.from_crs(wrf_proj.crs, wgs_proj.crs)
lon, lat = transformer.transform(X, Y)

ds = ds.assign_coords(lon = (['y', 'x'], lon))
ds = ds.assign_coords(lat = (['y', 'x'], lat))
ds = ds.assign_coords(x = x)
ds = ds.assign_coords(y = y)

ds.x.attrs['axis'] = 'X'
ds.x.attrs['standard_name'] = 'projection_x_coordinate'
ds.x.attrs['long_name'] = 'x-coordinate in projected coordinate system'
ds.x.attrs['resolution'] = 1000.  # cell size

ds.y.attrs['axis'] = 'Y' 
ds.y.attrs['standard_name'] = 'projection_y_coordinate'
ds.y.attrs['long_name'] = 'y-coordinate in projected coordinate system'
ds.y.attrs['resolution'] = 1000.  # cell size

ds.lon.attrs['units'] = 'degrees_east'
ds.lon.attrs['standard_name'] = 'longitude' 
ds.lon.attrs['long_name'] = 'longitude'

ds.lat.attrs['units'] = 'degrees_north'
ds.lat.attrs['standard_name'] = 'latitude' 
ds.lat.attrs['long_name'] = 'latitude'

# add crs to netcdf file
ds.rio.write_crs(ds_meta.crs.attrs['spatial_ref'], inplace=True
                ).rio.set_spatial_dims(x_dim="x",
                                       y_dim="y",
                                       inplace=True,
                                       ).rio.write_coordinate_system(inplace=True);

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 200, y: 3840, x: 4608)
# Coordinates:
#   * time         (time) datetime64[ns] 2017-10-25T22:00:00 ... 2017-11-03T05:...
#     lon          (y, x) float64 -133.5 -133.5 -133.5 ... -75.91 -75.9 -75.9
#     lat          (y, x) float64 52.87 52.88 52.88 52.88 ... 20.08 20.08 20.08
#   * x            (x) float64 -2.303e+06 -2.302e+06 ... 2.303e+06 2.304e+06
#   * y            (y) float64 1.919e+06 1.918e+06 ... -1.919e+06 -1.92e+06
#     spatial_ref  int64 0
# Data variables:
#     LWDOWN       (time, y, x) float32 ...
#     PSFC         (time, y, x) float32 ...
#     Q2D          (time, y, x) float32 ...
#     RAINRATE     (time, y, x) float32 ...
#     SWDOWN       (time, y, x) float32 ...
#     T2D          (time, y, x) float32 ...
#     Times        (time) |S20 b'2017-10-25_22:00:00' ... b'2017-11-03_05:00:00'
#     U2D          (time, y, x) float32 ...
#     V2D          (time, y, x) float32 ...

# %% [markdown]
# ## Add spatial reference to the model domain

# %% [markdown]
# Load the geodatabase of our `ngen` domain. This can be obtained using the `ngen-hydrofabric-subset.ipynb` notebook.

# %%
# prepare geometries for spatial averaging
gdf = geopandas.read_file(f'{wb_id}/config/{wb_id.split("_")[0]}_upstream_subset.gpkg', layer='divides')

gdf['geometry'].values
# Out:
# <GeometryArray>
# [<MULTIPOLYGON (((1830855.002 2189955.006, 1830764.997 2190044.998, 1830704.9...>, <MULTIPOLYGON (((1831184.998 2189654.996, 1831275.003 2189505.002, 1831304.9...>]
# Length: 2, dtype: geometry

# %%
# convert these data into the projection of our forcing data
target_crs = pyproj.Proj(proj='lcc',
                       lat_1=30.,
                       lat_2=60., 
                       lat_0=40.0000076293945, lon_0=-97., # Center point
                       a=6370000, b=6370000) 

gdf = gdf.to_crs(target_crs.crs)

gdf['geometry'].values
# Out:
# <GeometryArray>
# [<MULTIPOLYGON (((1856218.546 355345.833, 1856126.447 355427.196, 1856066.582...>, <MULTIPOLYGON (((1856554.695 355076.306, 1856649.853 354937.259, 1856689.721...>]
# Length: 2, dtype: geometry

# %%
gdf
# Out:
#            id   divide_id        toid     type  ds_id   areasqkm  lengthkm  \
# 0  cat-698891  cat-698891  nex-698887  network    NaN  11.870088  1.723643
# 1  cat-698886  cat-698886  nex-698887  network    NaN   4.483801  2.680196
#
#    tot_drainage_areasqkm  has_flowline  \
# 0              11.870088          True
# 1               4.483801          True
#
#                                             geometry
# 0  MULTIPOLYGON (((1856218.546 355345.833, 185612...
# 1  MULTIPOLYGON (((1856554.695 355076.306, 185664...

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
# important step
# rechunk the dataset to solve the memory limit issue
ds = ds.chunk(chunks={'time':1})

# %% [markdown]
# ## Clip AORC to the extent of the subset hydrofabric geometries
#
# Analysis of Record for Calibration (AORC)

# %% [markdown]
# Add catchment ids to the geodataset. These will be used to perform zonal statistics later on.

# %%
# %%time

# create zonal id column
gdf['cat'] = gdf.id.str.split('-').str[-1].astype(int)

# clip AORC to the extent of the hydrofabric geometries
ds = ds.rio.clip(gdf.geometry.values,
                 gdf.crs,
                 drop=True,
                 invert=False, from_disk=True)

# select a single array of data to use as a template
lwdown_data = ds.isel(time=0).LWDOWN

# create a grid for the geocube
out_grid = make_geocube(
    vector_data=gdf,
    measurements=["cat"],
    like=ds # ensure the data are on the same grid
)

# add the catchment variable to the original dataset
ds = ds.assign_coords(cat = (['y','x'], out_grid.cat.data))

# compute the unique catchment IDs which will be used to compute zonal statistics
catchment_ids = numpy.unique(ds.cat.data[~numpy.isnan(ds.cat.data)])

print(f'The dataset contains {len(catchment_ids)} catchments')
# Out:
# The dataset contains 2 catchments
# CPU times: user 2.46 s, sys: 275 ms, total: 2.73 s
# Wall time: 2.57 s

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 200, y: 12, x: 3)
# Coordinates:
#   * time         (time) datetime64[ns] 2017-10-25T22:00:00 ... 2017-11-03T05:...
#     lon          (y, x) float64 dask.array<chunksize=(12, 3), meta=np.ndarray>
#     lat          (y, x) float64 dask.array<chunksize=(12, 3), meta=np.ndarray>
#   * x            (x) float64 1.856e+06 1.857e+06 1.858e+06
#   * y            (y) float64 3.635e+05 3.625e+05 ... 3.535e+05 3.525e+05
#     spatial_ref  int64 0
#     cat          (y, x) float64 nan 6.989e+05 6.989e+05 ... nan nan 6.989e+05
# Data variables:
#     LWDOWN       (time, y, x) float32 dask.array<chunksize=(1, 12, 3), meta=np.ndarray>
#     PSFC         (time, y, x) float32 dask.array<chunksize=(1, 12, 3), meta=np.ndarray>
#     Q2D          (time, y, x) float32 dask.array<chunksize=(1, 12, 3), meta=np.ndarray>
#     RAINRATE     (time, y, x) float32 dask.array<chunksize=(1, 12, 3), meta=np.ndarray>
#     SWDOWN       (time, y, x) float32 dask.array<chunksize=(1, 12, 3), meta=np.ndarray>
#     T2D          (time, y, x) float32 dask.array<chunksize=(1, 12, 3), meta=np.ndarray>
#     Times        (time) |S20 dask.array<chunksize=(1,), meta=np.ndarray>
#     U2D          (time, y, x) float32 dask.array<chunksize=(1, 12, 3), meta=np.ndarray>
#     V2D          (time, y, x) float32 dask.array<chunksize=(1, 12, 3), meta=np.ndarray>

# %% [markdown]
# ## Preview the gridded catchments over the watershed vector boundary

# %% [markdown]
# Note that the method we're using will associate grid cell with the watershed that it overlaps the most with. There are more advanced ways to create a mapping using various interpolation methods that will distribute values cells across all watershed boundaries that they intersect with. This is left as a future exercize.

# %%
figure, ax = plt.subplots(figsize=(10, 10))


# plot the gridded catchment mapping
ds.cat.plot()

## create a discrete color mapping such that each catchment 
## is represented by a single color
# cmap = colors.ListedColormap(['green', 'lightskyblue', 'cyan', 'red', 'navy'])
# bounds = [catchment_ids[0]] + [c+0.9 for c in catchment_ids]
# norm = colors.BoundaryNorm(bounds, cmap.N)
# ds.cat.plot(cmap=cmap, norm=norm, ax=ax)

# preview map geometries
map_wd = gdf.iloc[:].plot(ax=ax, linewidth=0.8, edgecolor='k', facecolor='None');

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

ax.set_title(f"{wb_id}", fontsize=20, y=1.03)
# Out:
# Text(0.5, 1.03, 'wb-698891')

# %% [markdown]
# ## Compute basin-averaged forcing data

# %% [markdown]
# Define functions that will be used to perform basin averages on the AORC data. These functions leverage `dask` to parallelize the computation.

# %%
# call once per catchment
# distribute zonal stats to sub processes
def perform_zonal_computation(ds, cat_id):

    # subset by catchment id
    ds_catchment = ds.where(ds.cat==cat_id, drop=True)
#    ds_catchement_future = client.scatter(ds_catchment, broadcast=True)
    
    delayed = []
    # loop over variables   
    for variable in ['LWDOWN', 'PSFC',
                     'Q2D', 'RAINRATE', 'SWDOWN',
                     'T2D', 'U2D', 'V2D']:
                
        delay = dask.delayed(compute_zonal_mean)(ds_catchment[variable], variable)
        delayed.append(delay)
        
    res = dask.compute(*delayed)
    
    # combine outputs (list of dicts) into a single dict.
    res = {k: v for d in res for k, v in d.items()}
    
    # return results
    return {f'cat-{int(cat_id)}': res}

def compute_zonal_mean(ds, variable):
    return {variable: ds.mean(dim=['x','y']).values}

# %% [markdown]
# Slice the data to the temporal period of our choice.

# %%
# define the start and end time of the data we want to use
start_time = f'{year}-10-26 00:00' 
end_time = f'{year}-11-02 00:00' # Tropical Storm Philippe | 26-Oct-2017 to 1-Nov-2017


# isolate the desired time period of our data
ds_subset = ds.sortby('time').sel(time=slice(start_time, end_time))

print(f'The dataset contains {len(ds_subset.time)} timesteps')
# Out:
# The dataset contains 169 timesteps

# %%
print(f'Available time range: {ds_subset.Times.min().values.item()} -> {ds_subset.Times.max().values.item()}')
# Out:
# Available time range: b'2017-10-26_00:00:00' -> b'2017-11-02_00:00:00'

# %% [markdown]
# Let's rechunk our data now that we have many fewer elements.

# %%
ds_subset = ds_subset.chunk(chunks={'time': 1000})

# %%
ds_subset.chunks
# Out:
# Frozen({'y': (12,), 'x': (3,), 'time': (169,)})

# %% [markdown]
# Drop all data that we don't need. The goal here is to make the dataset as small as possible before we start running computations on the data.

# %%
# drop unused coordinates
ds_subset = ds_subset.drop(['lat','lon'])

# %% [markdown]
# Tell `dask` to perform the subsetting computations on the data now. That way when we process the zonal statistics, the entire dataset won't need to be moved around. This will save a considerable amount of processing in future steps time.

# %%
# %%time 
ds_subset = ds_subset.compute()
# Out:
# CPU times: user 47.6 s, sys: 8.83 s, total: 56.4 s
# Wall time: 6min 35s

# %% [markdown]
# Scatter the dataset to the cluster so all workers will have access to it. This is good practice and especially necessary if working on a large dataset.

# %%
# %%time
scattered_ds = client.scatter(ds_subset, broadcast=True)
# Out:
# CPU times: user 30.3 ms, sys: 4.63 ms, total: 35 ms
# Wall time: 50.7 ms

# %% [markdown]
# Build a list of `delayed` tasks. This will not execute the computation.

# %%
# %%time
delayed = []

# loop over each catchment in our domain
# create delayed tasks to compute zonal mean
for cat_id in catchment_ids:
    delay = dask.delayed(perform_zonal_computation)(scattered_ds, cat_id)
    delayed.append(delay)
# Out:
# CPU times: user 559 µs, sys: 0 ns, total: 559 µs
# Wall time: 500 µs

# %% [markdown]
# Invoke the computation using `dask.compute`.

# %%
# %%time 

# run the computation
results = dask.compute(*delayed)
# Out:
# CPU times: user 58.7 ms, sys: 9.26 ms, total: 67.9 ms
# Wall time: 127 ms

# %% [markdown]
# Save the basin averaged meteorological data in the format expected by `ngen`.

# %% [markdown]
# The summarized AORC variables need to be mapped to the `ngen` model that we'll be using. The following table illustrates the mapping.
#
# |AORC Variable Name|NGEN Variable Name|Description|
# |---|---|---|
# | LWDOWN   | DLWRF_surface         | Surface downward long-wave radiation flux (W m-2)
# | PSFC     | PRES_surface          | Surface Pressure (Pa)
# | Q2D      | SPFH_2maboveground    | 2-m Specific Humidity (kg kg-1)
# | RAINRATE | ---                   | precipitation_flux (mm s^-1)
# | SWDOWN   | DSWRF_surface         | Surface downward short-wave radiation flux (W m-2)
# | T2D      | TMP_2maboveground     | 2-m Air Temperature (K)
# | U2D      | UGRD_10maboveground   | 10-m U-component of wind (m s-1)
# | V2D      | VGRD_10maboveground   | 10-m V-component of wind (m s-1)
# | ---      | APCP_surface          | Surface precipitation (kg/m^2)
#
# Note: our `ngen` model is expecting shortwave and longwave radiation at a height of 0 meters above ground whereas the AORC data has values are 2 meters above ground.
#
# References: [tshirt_c.h](https://github.com/NOAA-OWP/ngen/blob/f2725dfbb52f3af5083ce927e69733edbf059f57/models/tshirt/include/tshirt_c.h#L52), [sample forcing csv](https://github.com/NOAA-OWP/ngen/blob/master/data/forcing/cat-27_2015-12-01%2000_00_00_2015-12-30%2023_00_00.csv)

# %% [markdown]
# ## Save data as csv files

# %%
# compute the date range for our data using start and end times
# that were used in the subsetting process.
dates = pandas.date_range(start_time, end_time, freq="60min")

# save the zonal means for each catchment
for dat in tqdm(results):
    for cat in dat:
        df = pandas.DataFrame({k:list(v) for k,v in dat[cat].items()})
        df.fillna(0., inplace=True)
        
        # convert rainrate from mm/s to kg/m2
        # mm/s - mm/hr = df.RAINRATE * 3600
        # since the timestep is one hour, this is effectively the total rain in mm.
        # 1 mm of rainfall is equal to 1kg/m2 so our conversion is:
        # NOTE: we should only be considering the fraction of liquid precip which can
        #       be computed using LQFRAC. However LQFRAC is zero for our data which 
        #       does not seem correct, so we'll assume that all precip is liquid. This
        #       is something that needs to be revisited.
        df['APCP_surface'] = df.RAINRATE * 3600

        # rename columns to match the variable names expected by the ngen t-shirt model
        df.rename(columns={
            'LWDOWN'   : 'DLWRF_surface',
            'PSFC'     : 'PRES_surface',
            'Q2D'      : 'SPFH_2maboveground',
            'SWDOWN'   : 'DSWRF_surface',
            'T2D'      : 'TMP_2maboveground',
            'U2D'      : 'UGRD_10maboveground',
            'V2D'      : 'VGRD_10maboveground',
            'RAINRATE' : 'precip_rate',
            },
                  inplace=True)
        
        # add the time index
        df['time'] = dates
        df.set_index('time', inplace=True)


        # write to file
        with open(f'{wb_id}/forcings/{cat}.csv', 'w') as f:
            # Note: saving "precip_rate" because this column exists in the example 
            #       forcing files. It's not clear if this is being used or not.
            df.to_csv(f,
                      columns = ['APCP_surface',
                                 'DLWRF_surface',
                                 'DSWRF_surface',
                                 'PRES_surface',
                                 'SPFH_2maboveground',
                                 'TMP_2maboveground',
                                 'UGRD_10maboveground',
                                 'VGRD_10maboveground',
                                 'precip_rate'])
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
df
# Out:
#                      DLWRF_surface   PRES_surface  SPFH_2maboveground  \
# time
# 2017-10-26 00:00:00     333.697205  100925.531250            0.008963
# 2017-10-26 01:00:00     333.697205  100925.531250            0.008963
# 2017-10-26 02:00:00     308.586548  100970.406250            0.008149
# 2017-10-26 03:00:00     308.586548  100970.406250            0.008149
# 2017-10-26 04:00:00     308.586548  100970.406250            0.008149
# ...                            ...            ...                 ...
# 2017-11-01 20:00:00     363.579193  102419.507812            0.013074
# 2017-11-01 21:00:00     363.579193  102419.507812            0.013074
# 2017-11-01 22:00:00     363.579193  102419.507812            0.013074
# 2017-11-01 23:00:00     411.991730  102367.351562            0.013697
# 2017-11-02 00:00:00     411.991730  102367.351562            0.013697
#
#                      precip_rate  DSWRF_surface  TMP_2maboveground  \
# time
# 2017-10-26 00:00:00     0.000002            0.0         293.730896
# 2017-10-26 01:00:00     0.000002            0.0         293.730896
# 2017-10-26 02:00:00     0.000009            0.0         293.155792
# 2017-10-26 03:00:00     0.000009            0.0         293.155792
# 2017-10-26 04:00:00     0.000009            0.0         293.155792
# ...                          ...            ...                ...
# 2017-11-01 20:00:00     0.000000            0.0         295.983368
# 2017-11-01 21:00:00     0.000000            0.0         295.983368
# 2017-11-01 22:00:00     0.000000            0.0         295.983368
# 2017-11-01 23:00:00     0.000003            0.0         296.482574
# 2017-11-02 00:00:00     0.000003            0.0         296.482574
#
#                      UGRD_10maboveground  VGRD_10maboveground  APCP_surface
# time
# 2017-10-26 00:00:00             5.902008            -0.907043      0.005504
# 2017-10-26 01:00:00             5.902008            -0.907043      0.005504
# 2017-10-26 02:00:00             8.333531            -5.988395      0.030983
# 2017-10-26 03:00:00             8.333531            -5.988395      0.030983
# 2017-10-26 04:00:00             8.333531            -5.988395      0.030983
# ...                                  ...                  ...           ...
# 2017-11-01 20:00:00            -3.932825             2.443230      0.000000
# 2017-11-01 21:00:00            -3.932825             2.443230      0.000000
# 2017-11-01 22:00:00            -3.932825             2.443230      0.000000
# 2017-11-01 23:00:00            -6.587027             1.071427      0.009115
# 2017-11-02 00:00:00            -6.587027             1.071427      0.009115
#
# [169 rows x 9 columns]

# %%
dates
# Out:
# DatetimeIndex(['2017-10-26 00:00:00', '2017-10-26 01:00:00',
#                '2017-10-26 02:00:00', '2017-10-26 03:00:00',
#                '2017-10-26 04:00:00', '2017-10-26 05:00:00',
#                '2017-10-26 06:00:00', '2017-10-26 07:00:00',
#                '2017-10-26 08:00:00', '2017-10-26 09:00:00',
#                ...
#                '2017-11-01 15:00:00', '2017-11-01 16:00:00',
#                '2017-11-01 17:00:00', '2017-11-01 18:00:00',
#                '2017-11-01 19:00:00', '2017-11-01 20:00:00',
#                '2017-11-01 21:00:00', '2017-11-01 22:00:00',
#                '2017-11-01 23:00:00', '2017-11-02 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq='60T')

# %%
# check the number of catchments. 
print(gdf.shape[0])
print(len(results))

# If these are not equal, run the following code cell.
# Out:
# 2
# 2

# %% [markdown]
# Here is an example showing why some catchments are missing in the results.

# %% [markdown]
# <img src="./figures/missing_catchment_example.png">

# %%
computed_catchments = [list(r.keys())[0] for r in results]
for cat_id in gdf['cat'].values:
    known_catchment = f'cat-{int(cat_id)}'
    if known_catchment not in computed_catchments:
        print(f'Creating Synthetic Forcing for {known_catchment}')
        synthetic_df = pandas.DataFrame(0, index=df.index, columns=['APCP_surface',
                                                                    'DLWRF_surface',
                                                                    'PRES_surface',
                                                                    'SPFH_2maboveground',
                                                                    'DSWRF_surface',
                                                                    'TMP_2maboveground',
                                                                    'UGRD_10maboveground',
                                                                    'VGRD_10maboveground',
                                                                    'precip_rate'])
        # write to file
        with open(f'{wb_id}/forcings/{known_catchment}.csv', 'w') as f:
            df.to_csv(f,
                      columns = ['APCP_surface',
                                 'DLWRF_surface',
                                 'DSWRF_surface',
                                 'PRES_surface',
                                 'SPFH_2maboveground',
                                 'TMP_2maboveground',
                                 'UGRD_10maboveground',
                                 'VGRD_10maboveground',
                                 'precip_rate'])
# Out:
# Creating Synthetic Forcing for cat-698886

# %% [markdown]
# ## Run all the watersheds in the New York City

# %%
# List of watersheds in NYC area
ids_list = ['wb-694856', 'wb-694725', 'wb-694855', 'wb-694724', 'wb-694854', 'wb-694723', 'wb-694722']

# 'wb-698891' is giving parameter error. Run this watershed separately 

for wb_id in tqdm(ids_list):
    
    ################################################################
    ### Add spatial reference to the model domain 
    ################################################################
    
    # prepare geometries for spatial averaging
    gdf = geopandas.read_file(f'{wb_id}/config/{wb_id.split("_")[0]}_upstream_subset.gpkg', layer='divides')

    # convert these data into the projection of our forcing data
    target_crs = pyproj.Proj(proj='lcc',
                           lat_1=30.,
                           lat_2=60., 
                           lat_0=40.0000076293945, lon_0=-97., # Center point
                           a=6370000, b=6370000) 

    gdf = gdf.to_crs(target_crs.crs)
    
    # important step
    # rechunk the dataset to solve the memory limit issue
    ds = ds.chunk(chunks={'time':1})
    
    print(f"Preparation of geometries for {wb_id} watershed is done!")
    
    #################################################################
    ### Clip AORC to the extent of the subset hydrofabric geometries
    #################################################################
    
    # create zonal id column
    gdf['cat'] = gdf.id.str.split('-').str[-1].astype(int)

    # clip AORC to the extent of the hydrofabric geometries
    ds = ds.rio.clip(gdf.geometry.values,
                     gdf.crs,
                     drop=True,
                     invert=False)

    # select a single array of data to use as a template
    # lwdown_data = ds.isel(time=0).LWDOWN

    # create a grid for the geocube
    out_grid = make_geocube(
        vector_data=gdf,
        measurements=["cat"],
        like=ds # ensure the data are on the same grid
    )

    # add the catchment variable to the original dataset
    ds = ds.assign_coords(cat = (['y','x'], out_grid.cat.data))

    # compute the unique catchment IDs which will be used to compute zonal statistics
    catchment_ids = numpy.unique(ds.cat.data[~numpy.isnan(ds.cat.data)])

    print(f'The dataset contains {len(catchment_ids)} catchments')
    
    print(f"Clipping AORC to the extent of the subset hydrofabric geometries for {wb_id} watershed is done!")
    
    ######################################################################
    ### Preview the gridded catchments over the watershed vector boundary
    ######################################################################
    
    figure, ax = plt.subplots(figsize=(10, 14))


    # plot the gridded catchment mapping
    ds.cat.plot()

    ## create a discrete color mapping such that each catchment 
    ## is represented by a single color
    # cmap = colors.ListedColormap(['green', 'lightskyblue', 'cyan', 'red', 'navy'])
    # bounds = [catchment_ids[0]] + [c+0.9 for c in catchment_ids]
    # norm = colors.BoundaryNorm(bounds, cmap.N)
    # ds.cat.plot(cmap=cmap, norm=norm, ax=ax)

    # preview map geometries
    map_wd = gdf.iloc[:].plot(ax=ax, linewidth=0.8, edgecolor='k', facecolor='None');

    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    ax.set_title(f"{wb_id}", fontsize=20, y=1.03)
    
    plt.show()

    #####################################################################
    ### Compute basin-averaged forcing data
    #####################################################################
    
    # define the start and end time of the data we want to use
    start_time = f'{year}-10-26 00:00' 
    end_time = f'{year}-11-02 00:00' # Tropical Storm Philippe | 26-Oct-2017 to 1-Nov-2017


    # isolate the desired time period of our data
    ds_subset = ds.sortby('time').sel(time=slice(start_time, end_time))

    print(f'The dataset contains {len(ds_subset.time)} timesteps')
    
    # Let's rechunk our data now that we have many fewer elements.
    ds_subset = ds_subset.chunk(chunks={'time': 1000})
    
    print(ds_subset.chunks)
    
    ## Drop all data that we don't need. 
    ## The goal here is to make the dataset as small as possible before we start running computations on the data.
    # drop unused coordinates
    ds_subset = ds_subset.drop(['lat','lon'])
    
    ## Tell dask to perform the subsetting computations on the data now.
    ds_subset = ds_subset.compute()
    
    # Scatter the dataset to the cluster so all workers will have access to it.
    scattered_ds = client.scatter(ds_subset, broadcast=True)
    
    # Build a list of delayed tasks. This will not execute the computation
    delayed = []

    # loop over each catchment in our domain
    # create delayed tasks to compute zonal mean
    for cat_id in catchment_ids:
        delay = dask.delayed(perform_zonal_computation)(scattered_ds, cat_id)
        delayed.append(delay)
        
    # Invoke the computation using dask.compute.
    # run the computation
    results = dask.compute(*delayed)
    
    print(f"Computation of basin-averaged forcing data for {wb_id} watershed is done!")
    
    #####################################################################
    ### Save data as csv files
    #####################################################################
    
    # compute the date range for our data using start and end times
    # that were used in the subsetting process.
    dates = pd.date_range(start_time, end_time, freq="60min")

    # save the zonal means for each catchment
    for dat in tqdm(results):
        for cat in dat:
            df = pd.DataFrame({k:list(v) for k,v in dat[cat].items()})
            df.fillna(0., inplace=True)

            # convert rainrate from mm/s to kg/m2
            # mm/s - mm/hr = df.RAINRATE * 3600
            # since the timestep is one hour, this is effectively the total rain in mm.
            # 1 mm of rainfall is equal to 1kg/m2 so our conversion is:
            # NOTE: we should only be considering the fraction of liquid precip which can
            #       be computed using LQFRAC. However LQFRAC is zero for our data which 
            #       does not seem correct, so we'll assume that all precip is liquid. This
            #       is something that needs to be revisited.
            df['APCP_surface'] = df.RAINRATE * 3600

            # rename columns to match the variable names expected by the ngen t-shirt model
            df.rename(columns={
                'LWDOWN'   : 'DLWRF_surface',
                'PSFC'     : 'PRES_surface',
                'Q2D'      : 'SPFH_2maboveground',
                'SWDOWN'   : 'DSWRF_surface',
                'T2D'      : 'TMP_2maboveground',
                'U2D'      : 'UGRD_10maboveground',
                'V2D'      : 'VGRD_10maboveground',
                'RAINRATE' : 'precip_rate',
                },
                      inplace=True)

            # add the time index
            df['time'] = dates
            df.set_index('time', inplace=True)


            # write to file
            with open(f'{wb_id}/forcings/{cat}.csv', 'w') as f:
                # Note: saving "precip_rate" because this column exists in the example 
                #       forcing files. It's not clear if this is being used or not.
                df.to_csv(f,
                          columns = ['APCP_surface',
                                     'DLWRF_surface',
                                     'DSWRF_surface',
                                     'PRES_surface',
                                     'SPFH_2maboveground',
                                     'TMP_2maboveground',
                                     'UGRD_10maboveground',
                                     'VGRD_10maboveground',
                                     'precip_rate'])
                
    # check the number of catchments. 
    print(gdf.shape[0])
    print(len(results))

    # check if the shape of 'gdf' and the length of 'results' are equal
    if gdf.shape[0] != len(results):
        computed_catchments = [list(r.keys())[0] for r in results]
        for cat_id in gdf['cat'].values:
            known_catchment = f'cat-{int(cat_id)}'
            if known_catchment not in computed_catchments:
                print(f'Creating Synthetic Forcing for {known_catchment}')
                synthetic_df = pd.DataFrame(0, index=df.index, columns=['APCP_surface',
                                                                        'DLWRF_surface',
                                                                        'PRES_surface',
                                                                        'SPFH_2maboveground',
                                                                        'DSWRF_surface',
                                                                        'TMP_2maboveground',
                                                                        'UGRD_10maboveground',
                                                                        'VGRD_10maboveground',
                                                                        'precip_rate'])
                # write to file
                with open(f'{wb_id}/forcings/{known_catchment}.csv', 'w') as f:
                    synthetic_df.to_csv(f,
                              columns = ['APCP_surface',
                                         'DLWRF_surface',
                                         'DSWRF_surface',
                                         'PRES_surface',
                                         'SPFH_2maboveground',
                                         'TMP_2maboveground',
                                         'UGRD_10maboveground',
                                         'VGRD_10maboveground',
                                         'precip_rate'])
    else:
        print("The shape of 'gdf' and the length of 'results' are equal.")
            
    print(f"Processing of {wb_id} watershed is done!")
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Preparation of geometries for wb-694856 watershed is done!
# The dataset contains 4068 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694856 watershed is done!
# The dataset contains 169 timesteps
# Frozen({'y': (362,), 'x': (218,), 'time': (169,)})
# Computation of basin-averaged forcing data for wb-694856 watershed is done!
#   0%|          | 0/4068 [00:00<?, ?it/s]
# 4124
# 4068
# Creating Synthetic Forcing for cat-694734
# Creating Synthetic Forcing for cat-695825
# Creating Synthetic Forcing for cat-695826
# Creating Synthetic Forcing for cat-695124
# Creating Synthetic Forcing for cat-695661
# Creating Synthetic Forcing for cat-695128
# Creating Synthetic Forcing for cat-694758
# Creating Synthetic Forcing for cat-694993
# Creating Synthetic Forcing for cat-695145
# Creating Synthetic Forcing for cat-695384
# Creating Synthetic Forcing for cat-695839
# Creating Synthetic Forcing for cat-697926
# Creating Synthetic Forcing for cat-695392
# Creating Synthetic Forcing for cat-694872
# Creating Synthetic Forcing for cat-697241
# Creating Synthetic Forcing for cat-697758
# Creating Synthetic Forcing for cat-695072
# Creating Synthetic Forcing for cat-697767
# Creating Synthetic Forcing for cat-694921
# Creating Synthetic Forcing for cat-698420
# Creating Synthetic Forcing for cat-694942
# Creating Synthetic Forcing for cat-698405
# Creating Synthetic Forcing for cat-697707
# Creating Synthetic Forcing for cat-695107
# Creating Synthetic Forcing for cat-698398
# Creating Synthetic Forcing for cat-695111
# Creating Synthetic Forcing for cat-695553
# Creating Synthetic Forcing for cat-696857
# Creating Synthetic Forcing for cat-694897
# Creating Synthetic Forcing for cat-698331
# Creating Synthetic Forcing for cat-695642
# Creating Synthetic Forcing for cat-695938
# Creating Synthetic Forcing for cat-695489
# Creating Synthetic Forcing for cat-698199
# Creating Synthetic Forcing for cat-696382
# Creating Synthetic Forcing for cat-694800
# Creating Synthetic Forcing for cat-698213
# Creating Synthetic Forcing for cat-695264
# Creating Synthetic Forcing for cat-697551
# Creating Synthetic Forcing for cat-698225
# Creating Synthetic Forcing for cat-696582
# Creating Synthetic Forcing for cat-695254
# Creating Synthetic Forcing for cat-697475
# Creating Synthetic Forcing for cat-698057
# Creating Synthetic Forcing for cat-695634
# Creating Synthetic Forcing for cat-697440
# Creating Synthetic Forcing for cat-695154
# Creating Synthetic Forcing for cat-697037
# Creating Synthetic Forcing for cat-698009
# Creating Synthetic Forcing for cat-697423
# Creating Synthetic Forcing for cat-698011
# Creating Synthetic Forcing for cat-695051
# Creating Synthetic Forcing for cat-695540
# Creating Synthetic Forcing for cat-697414
# Creating Synthetic Forcing for cat-697427
# Creating Synthetic Forcing for cat-698017
# Processing of wb-694856 watershed is done!
# Preparation of geometries for wb-694725 watershed is done!
# The dataset contains 4 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694725 watershed is done!
# The dataset contains 169 timesteps
# Frozen({'y': (22,), 'x': (11,), 'time': (169,)})
# Computation of basin-averaged forcing data for wb-694725 watershed is done!
#   0%|          | 0/4 [00:00<?, ?it/s]
# 4
# 4
# The shape of 'gdf' and the length of 'results' are equal.
# Processing of wb-694725 watershed is done!
# Preparation of geometries for wb-694855 watershed is done!
# The dataset contains 4 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694855 watershed is done!
# The dataset contains 169 timesteps
# Frozen({'y': (16,), 'x': (4,), 'time': (169,)})
# Computation of basin-averaged forcing data for wb-694855 watershed is done!
#   0%|          | 0/4 [00:00<?, ?it/s]
# 4123
# 4
# Creating Synthetic Forcing for cat-696657
# Creating Synthetic Forcing for cat-696466
# Creating Synthetic Forcing for cat-694726
# Creating Synthetic Forcing for cat-696467
# Creating Synthetic Forcing for cat-698646
# Creating Synthetic Forcing for cat-696468
# Creating Synthetic Forcing for cat-697852
# Creating Synthetic Forcing for cat-696945
# Creating Synthetic Forcing for cat-698644
# Creating Synthetic Forcing for cat-697299
# Creating Synthetic Forcing for cat-698645
# Creating Synthetic Forcing for cat-694727
# Creating Synthetic Forcing for cat-697851
# Creating Synthetic Forcing for cat-694728
# Creating Synthetic Forcing for cat-696964
# Creating Synthetic Forcing for cat-695784
# Creating Synthetic Forcing for cat-695785
# Creating Synthetic Forcing for cat-698647
# Creating Synthetic Forcing for cat-697300
# Creating Synthetic Forcing for cat-697301
# Creating Synthetic Forcing for cat-697853
# Creating Synthetic Forcing for cat-695786
# Creating Synthetic Forcing for cat-698648
# Creating Synthetic Forcing for cat-696946
# Creating Synthetic Forcing for cat-694729
# Creating Synthetic Forcing for cat-697854
# Creating Synthetic Forcing for cat-694730
# Creating Synthetic Forcing for cat-696658
# Creating Synthetic Forcing for cat-696659
# Creating Synthetic Forcing for cat-697302
# Creating Synthetic Forcing for cat-694731
# Creating Synthetic Forcing for cat-694732
# Creating Synthetic Forcing for cat-698642
# Creating Synthetic Forcing for cat-696208
# Creating Synthetic Forcing for cat-698641
# Creating Synthetic Forcing for cat-697298
# Creating Synthetic Forcing for cat-697334
# Creating Synthetic Forcing for cat-696209
# Creating Synthetic Forcing for cat-696210
# Creating Synthetic Forcing for cat-698643
# Creating Synthetic Forcing for cat-696306
# Creating Synthetic Forcing for cat-696307
# Creating Synthetic Forcing for cat-698649
# Creating Synthetic Forcing for cat-697855
# Creating Synthetic Forcing for cat-694733
# Creating Synthetic Forcing for cat-698692
# Creating Synthetic Forcing for cat-695512
# Creating Synthetic Forcing for cat-698650
# Creating Synthetic Forcing for cat-695513
# Creating Synthetic Forcing for cat-697303
# Creating Synthetic Forcing for cat-696947
# Creating Synthetic Forcing for cat-696948
# Creating Synthetic Forcing for cat-695514
# Creating Synthetic Forcing for cat-698651
# Creating Synthetic Forcing for cat-695781
# Creating Synthetic Forcing for cat-696661
# Creating Synthetic Forcing for cat-697860
# Creating Synthetic Forcing for cat-695782
# Creating Synthetic Forcing for cat-697859
# Creating Synthetic Forcing for cat-696211
# Creating Synthetic Forcing for cat-696949
# Creating Synthetic Forcing for cat-697861
# Creating Synthetic Forcing for cat-695783
# Creating Synthetic Forcing for cat-695515
# Creating Synthetic Forcing for cat-697304
# Creating Synthetic Forcing for cat-696662
# Creating Synthetic Forcing for cat-696660
# Creating Synthetic Forcing for cat-697858
# Creating Synthetic Forcing for cat-697857
# Creating Synthetic Forcing for cat-697862
# Creating Synthetic Forcing for cat-697863
# Creating Synthetic Forcing for cat-695516
# Creating Synthetic Forcing for cat-697856
# Creating Synthetic Forcing for cat-694734
# Creating Synthetic Forcing for cat-694735
# Creating Synthetic Forcing for cat-697850
# Creating Synthetic Forcing for cat-697864
# Creating Synthetic Forcing for cat-697888
# Creating Synthetic Forcing for cat-698683
# Creating Synthetic Forcing for cat-698640
# Creating Synthetic Forcing for cat-694736
# Creating Synthetic Forcing for cat-698652
# Creating Synthetic Forcing for cat-695821
# Creating Synthetic Forcing for cat-697306
# Creating Synthetic Forcing for cat-695822
# Creating Synthetic Forcing for cat-698655
# Creating Synthetic Forcing for cat-696212
# Creating Synthetic Forcing for cat-698654
# Creating Synthetic Forcing for cat-698691
# Creating Synthetic Forcing for cat-696213
# Creating Synthetic Forcing for cat-697307
# Creating Synthetic Forcing for cat-698653
# Creating Synthetic Forcing for cat-695823
# Creating Synthetic Forcing for cat-698639
# Creating Synthetic Forcing for cat-696215
# Creating Synthetic Forcing for cat-697305
# Creating Synthetic Forcing for cat-694737
# Creating Synthetic Forcing for cat-695182
# Creating Synthetic Forcing for cat-695183
# Creating Synthetic Forcing for cat-697849
# Creating Synthetic Forcing for cat-698633
# Creating Synthetic Forcing for cat-698632
# Creating Synthetic Forcing for cat-698634
# Creating Synthetic Forcing for cat-695184
# Creating Synthetic Forcing for cat-696943
# Creating Synthetic Forcing for cat-698635
# Creating Synthetic Forcing for cat-696944
# Creating Synthetic Forcing for cat-697847
# Creating Synthetic Forcing for cat-698685
# Creating Synthetic Forcing for cat-697848
# Creating Synthetic Forcing for cat-698636
# Creating Synthetic Forcing for cat-695185
# Creating Synthetic Forcing for cat-697333
# Creating Synthetic Forcing for cat-698631
# Creating Synthetic Forcing for cat-698630
# Creating Synthetic Forcing for cat-695186
# Creating Synthetic Forcing for cat-698684
# Creating Synthetic Forcing for cat-698629
# Creating Synthetic Forcing for cat-695187
# Creating Synthetic Forcing for cat-698637
# Creating Synthetic Forcing for cat-698628
# Creating Synthetic Forcing for cat-698627
# Creating Synthetic Forcing for cat-698626
# Creating Synthetic Forcing for cat-695188
# Creating Synthetic Forcing for cat-697846
# Creating Synthetic Forcing for cat-695189
# Creating Synthetic Forcing for cat-695706
# Creating Synthetic Forcing for cat-695707
# Creating Synthetic Forcing for cat-698624
# Creating Synthetic Forcing for cat-696655
# Creating Synthetic Forcing for cat-696940
# Creating Synthetic Forcing for cat-697295
# Creating Synthetic Forcing for cat-696941
# Creating Synthetic Forcing for cat-695708
# Creating Synthetic Forcing for cat-697844
# Creating Synthetic Forcing for cat-695709
# Creating Synthetic Forcing for cat-698682
# Creating Synthetic Forcing for cat-696464
# Creating Synthetic Forcing for cat-697296
# Creating Synthetic Forcing for cat-697893
# Creating Synthetic Forcing for cat-698625
# Creating Synthetic Forcing for cat-696465
# Creating Synthetic Forcing for cat-696942
# Creating Synthetic Forcing for cat-697297
# Creating Synthetic Forcing for cat-695710
# Creating Synthetic Forcing for cat-695779
# Creating Synthetic Forcing for cat-697845
# Creating Synthetic Forcing for cat-695780
# Creating Synthetic Forcing for cat-698638
# Creating Synthetic Forcing for cat-696656
# Creating Synthetic Forcing for cat-695190
# Creating Synthetic Forcing for cat-697308
# Creating Synthetic Forcing for cat-697865
# Creating Synthetic Forcing for cat-694738
# Creating Synthetic Forcing for cat-697313
# Creating Synthetic Forcing for cat-695320
# Creating Synthetic Forcing for cat-696955
# Creating Synthetic Forcing for cat-697873
# Creating Synthetic Forcing for cat-695321
# Creating Synthetic Forcing for cat-698664
# Creating Synthetic Forcing for cat-695322
# Creating Synthetic Forcing for cat-698663
# Creating Synthetic Forcing for cat-697872
# Creating Synthetic Forcing for cat-695323
# Creating Synthetic Forcing for cat-697311
# Creating Synthetic Forcing for cat-697312
# Creating Synthetic Forcing for cat-698662
# Creating Synthetic Forcing for cat-695324
# Creating Synthetic Forcing for cat-695325
# Creating Synthetic Forcing for cat-696664
# Creating Synthetic Forcing for cat-697871
# Creating Synthetic Forcing for cat-695326
# Creating Synthetic Forcing for cat-695827
# Creating Synthetic Forcing for cat-698665
# Creating Synthetic Forcing for cat-695828
# Creating Synthetic Forcing for cat-697895
# Creating Synthetic Forcing for cat-698666
# Creating Synthetic Forcing for cat-698667
# Creating Synthetic Forcing for cat-695829
# Creating Synthetic Forcing for cat-698668
# Creating Synthetic Forcing for cat-698669
# Creating Synthetic Forcing for cat-695830
# Creating Synthetic Forcing for cat-698670
# Creating Synthetic Forcing for cat-697314
# Creating Synthetic Forcing for cat-697875
# Creating Synthetic Forcing for cat-697874
# Creating Synthetic Forcing for cat-695327
# Creating Synthetic Forcing for cat-696952
# Creating Synthetic Forcing for cat-696953
# Creating Synthetic Forcing for cat-696954
# Creating Synthetic Forcing for cat-696951
# Creating Synthetic Forcing for cat-697870
# Creating Synthetic Forcing for cat-697878
# Creating Synthetic Forcing for cat-697879
# Creating Synthetic Forcing for cat-697877
# Creating Synthetic Forcing for cat-697876
# Creating Synthetic Forcing for cat-695328
# Creating Synthetic Forcing for cat-697889
# Creating Synthetic Forcing for cat-697890
# Creating Synthetic Forcing for cat-695329
# Creating Synthetic Forcing for cat-696469
# Creating Synthetic Forcing for cat-698659
# Creating Synthetic Forcing for cat-696470
# Creating Synthetic Forcing for cat-698658
# Creating Synthetic Forcing for cat-696471
# Creating Synthetic Forcing for cat-698661
# Creating Synthetic Forcing for cat-698660
# Creating Synthetic Forcing for cat-695824
# Creating Synthetic Forcing for cat-697868
# Creating Synthetic Forcing for cat-696020
# Creating Synthetic Forcing for cat-697866
# Creating Synthetic Forcing for cat-698656
# Creating Synthetic Forcing for cat-697867
# Creating Synthetic Forcing for cat-697309
# Creating Synthetic Forcing for cat-698657
# Creating Synthetic Forcing for cat-697310
# Creating Synthetic Forcing for cat-696021
# Creating Synthetic Forcing for cat-697869
# Creating Synthetic Forcing for cat-696663
# Creating Synthetic Forcing for cat-695825
# Creating Synthetic Forcing for cat-695826
# Creating Synthetic Forcing for cat-695330
# Creating Synthetic Forcing for cat-697315
# Creating Synthetic Forcing for cat-695331
# Creating Synthetic Forcing for cat-696668
# Creating Synthetic Forcing for cat-696214
# Creating Synthetic Forcing for cat-696950
# Creating Synthetic Forcing for cat-696956
# Creating Synthetic Forcing for cat-694739
# Creating Synthetic Forcing for cat-697294
# Creating Synthetic Forcing for cat-694740
# Creating Synthetic Forcing for cat-698671
# Creating Synthetic Forcing for cat-696472
# Creating Synthetic Forcing for cat-696305
# Creating Synthetic Forcing for cat-696957
# Creating Synthetic Forcing for cat-697293
# Creating Synthetic Forcing for cat-694741
# Creating Synthetic Forcing for cat-697841
# Creating Synthetic Forcing for cat-695360
# Creating Synthetic Forcing for cat-697291
# Creating Synthetic Forcing for cat-695361
# Creating Synthetic Forcing for cat-696110
# Creating Synthetic Forcing for cat-695362
# Creating Synthetic Forcing for cat-698687
# Creating Synthetic Forcing for cat-695363
# Creating Synthetic Forcing for cat-696463
# Creating Synthetic Forcing for cat-698686
# Creating Synthetic Forcing for cat-695364
# Creating Synthetic Forcing for cat-695365
# Creating Synthetic Forcing for cat-696939
# Creating Synthetic Forcing for cat-695366
# Creating Synthetic Forcing for cat-697842
# Creating Synthetic Forcing for cat-696654
# Creating Synthetic Forcing for cat-696965
# Creating Synthetic Forcing for cat-698623
# Creating Synthetic Forcing for cat-696966
# Creating Synthetic Forcing for cat-698622
# Creating Synthetic Forcing for cat-696967
# Creating Synthetic Forcing for cat-698621
# Creating Synthetic Forcing for cat-695367
# Creating Synthetic Forcing for cat-697843
# Creating Synthetic Forcing for cat-697840
# Creating Synthetic Forcing for cat-697290
# Creating Synthetic Forcing for cat-695368
# Creating Synthetic Forcing for cat-697292
# Creating Synthetic Forcing for cat-694742
# Creating Synthetic Forcing for cat-697880
# Creating Synthetic Forcing for cat-694743
# Creating Synthetic Forcing for cat-696022
# Creating Synthetic Forcing for cat-698673
# Creating Synthetic Forcing for cat-696023
# Creating Synthetic Forcing for cat-697318
# Creating Synthetic Forcing for cat-697317
# Creating Synthetic Forcing for cat-696024
# Creating Synthetic Forcing for cat-697319
# Creating Synthetic Forcing for cat-696025
# Creating Synthetic Forcing for cat-696303
# Creating Synthetic Forcing for cat-698620
# Creating Synthetic Forcing for cat-696304
# Creating Synthetic Forcing for cat-698672
# Creating Synthetic Forcing for cat-696669
# Creating Synthetic Forcing for cat-697320
# Creating Synthetic Forcing for cat-698674
# Creating Synthetic Forcing for cat-697321
# Creating Synthetic Forcing for cat-697316
# Creating Synthetic Forcing for cat-694744
# Creating Synthetic Forcing for cat-697322
# Creating Synthetic Forcing for cat-694745
# Creating Synthetic Forcing for cat-695967
# Creating Synthetic Forcing for cat-698675
# Creating Synthetic Forcing for cat-695968
# Creating Synthetic Forcing for cat-697323
# Creating Synthetic Forcing for cat-697881
# Creating Synthetic Forcing for cat-698609
# Creating Synthetic Forcing for cat-695969
# Creating Synthetic Forcing for cat-697882
# Creating Synthetic Forcing for cat-694746
# Creating Synthetic Forcing for cat-696461
# Creating Synthetic Forcing for cat-696462
# Creating Synthetic Forcing for cat-698619
# Creating Synthetic Forcing for cat-694747
# Creating Synthetic Forcing for cat-696460
# Creating Synthetic Forcing for cat-694748
# Creating Synthetic Forcing for cat-695748
# Creating Synthetic Forcing for cat-698787
# Creating Synthetic Forcing for cat-695749
# Creating Synthetic Forcing for cat-695750
# Creating Synthetic Forcing for cat-696665
# Creating Synthetic Forcing for cat-698676
# Creating Synthetic Forcing for cat-695751
# Creating Synthetic Forcing for cat-695752
# Creating Synthetic Forcing for cat-697891
# Creating Synthetic Forcing for cat-697892
# Creating Synthetic Forcing for cat-695753
# Creating Synthetic Forcing for cat-697883
# Creating Synthetic Forcing for cat-695754
# Creating Synthetic Forcing for cat-696960
# Creating Synthetic Forcing for cat-697884
# Creating Synthetic Forcing for cat-695755
# Creating Synthetic Forcing for cat-694749
# Creating Synthetic Forcing for cat-696111
# Creating Synthetic Forcing for cat-698690
# Creating Synthetic Forcing for cat-696112
# Creating Synthetic Forcing for cat-698679
# Creating Synthetic Forcing for cat-697325
# Creating Synthetic Forcing for cat-698678
# Creating Synthetic Forcing for cat-696113
# Creating Synthetic Forcing for cat-698677
# Creating Synthetic Forcing for cat-697324
# Creating Synthetic Forcing for cat-694750
# Creating Synthetic Forcing for cat-696216
# Creating Synthetic Forcing for cat-697839
# Creating Synthetic Forcing for cat-696217
# Creating Synthetic Forcing for cat-697838
# Creating Synthetic Forcing for cat-696458
# Creating Synthetic Forcing for cat-697289
# Creating Synthetic Forcing for cat-696459
# Creating Synthetic Forcing for cat-697326
# Creating Synthetic Forcing for cat-694751
# Creating Synthetic Forcing for cat-694752
# Creating Synthetic Forcing for cat-697825
# Creating Synthetic Forcing for cat-696650
# Creating Synthetic Forcing for cat-695112
# Creating Synthetic Forcing for cat-697894
# Creating Synthetic Forcing for cat-696207
# Creating Synthetic Forcing for cat-696968
# Creating Synthetic Forcing for cat-695113
# Creating Synthetic Forcing for cat-697281
# Creating Synthetic Forcing for cat-695114
# Creating Synthetic Forcing for cat-696931
# Creating Synthetic Forcing for cat-696932
# Creating Synthetic Forcing for cat-696649
# Creating Synthetic Forcing for cat-695115
# Creating Synthetic Forcing for cat-695116
# Creating Synthetic Forcing for cat-695813
# Creating Synthetic Forcing for cat-695814
# Creating Synthetic Forcing for cat-697826
# Creating Synthetic Forcing for cat-697283
# Creating Synthetic Forcing for cat-697284
# Creating Synthetic Forcing for cat-697282
# Creating Synthetic Forcing for cat-695815
# Creating Synthetic Forcing for cat-695117
# Creating Synthetic Forcing for cat-696651
# Creating Synthetic Forcing for cat-695118
# Creating Synthetic Forcing for cat-695893
# Creating Synthetic Forcing for cat-695894
# Creating Synthetic Forcing for cat-697279
# Creating Synthetic Forcing for cat-697824
# Creating Synthetic Forcing for cat-697280
# Creating Synthetic Forcing for cat-695895
# Creating Synthetic Forcing for cat-698613
# Creating Synthetic Forcing for cat-697328
# Creating Synthetic Forcing for cat-695896
# Creating Synthetic Forcing for cat-696670
# Creating Synthetic Forcing for cat-696671
# Creating Synthetic Forcing for cat-696672
# Creating Synthetic Forcing for cat-695897
# Creating Synthetic Forcing for cat-696930
# Creating Synthetic Forcing for cat-698614
# Creating Synthetic Forcing for cat-695119
# Creating Synthetic Forcing for cat-698612
# Creating Synthetic Forcing for cat-695120
# Creating Synthetic Forcing for cat-698611
# Creating Synthetic Forcing for cat-698615
# Creating Synthetic Forcing for cat-695121
# Creating Synthetic Forcing for cat-695961
# Creating Synthetic Forcing for cat-695962
# Creating Synthetic Forcing for cat-697827
# Creating Synthetic Forcing for cat-695963
# Creating Synthetic Forcing for cat-697331
# Creating Synthetic Forcing for cat-697332
# Creating Synthetic Forcing for cat-695964
# Creating Synthetic Forcing for cat-697285
# Creating Synthetic Forcing for cat-696451
# Creating Synthetic Forcing for cat-696452
# Creating Synthetic Forcing for cat-697828
# Creating Synthetic Forcing for cat-695965
# Creating Synthetic Forcing for cat-697330
# Creating Synthetic Forcing for cat-695966
# Creating Synthetic Forcing for cat-695122
# Creating Synthetic Forcing for cat-697823
# Creating Synthetic Forcing for cat-695123
# Creating Synthetic Forcing for cat-696652
# Creating Synthetic Forcing for cat-695898
# Creating Synthetic Forcing for cat-697829
# Creating Synthetic Forcing for cat-695899
# Creating Synthetic Forcing for cat-695124
# Creating Synthetic Forcing for cat-697830
# Creating Synthetic Forcing for cat-695125
# Creating Synthetic Forcing for cat-698616
# Creating Synthetic Forcing for cat-696453
# Creating Synthetic Forcing for cat-697822
# Creating Synthetic Forcing for cat-696647
# Creating Synthetic Forcing for cat-696648
# Creating Synthetic Forcing for cat-697286
# Creating Synthetic Forcing for cat-695126
# Creating Synthetic Forcing for cat-695888
# Creating Synthetic Forcing for cat-695889
# Creating Synthetic Forcing for cat-695890
# Creating Synthetic Forcing for cat-696448
# Creating Synthetic Forcing for cat-697821
# Creating Synthetic Forcing for cat-695891
# Creating Synthetic Forcing for cat-695892
# Creating Synthetic Forcing for cat-696449
# Creating Synthetic Forcing for cat-696450
# Creating Synthetic Forcing for cat-696933
# Creating Synthetic Forcing for cat-697287
# Creating Synthetic Forcing for cat-695127
# Creating Synthetic Forcing for cat-697837
# Creating Synthetic Forcing for cat-695654
# Creating Synthetic Forcing for cat-697836
# Creating Synthetic Forcing for cat-695655
# Creating Synthetic Forcing for cat-698617
# Creating Synthetic Forcing for cat-695656
# Creating Synthetic Forcing for cat-696936
# Creating Synthetic Forcing for cat-696937
# Creating Synthetic Forcing for cat-695657
# Creating Synthetic Forcing for cat-696454
# Creating Synthetic Forcing for cat-696455
# Creating Synthetic Forcing for cat-695816
# Creating Synthetic Forcing for cat-697833
# Creating Synthetic Forcing for cat-695817
# Creating Synthetic Forcing for cat-697834
# Creating Synthetic Forcing for cat-695818
# Creating Synthetic Forcing for cat-697832
# Creating Synthetic Forcing for cat-695819
# Creating Synthetic Forcing for cat-696934
# Creating Synthetic Forcing for cat-696935
# Creating Synthetic Forcing for cat-697835
# Creating Synthetic Forcing for cat-695820
# Creating Synthetic Forcing for cat-695658
# Creating Synthetic Forcing for cat-698689
# Creating Synthetic Forcing for cat-695659
# Creating Synthetic Forcing for cat-697831
# Creating Synthetic Forcing for cat-695660
# Creating Synthetic Forcing for cat-695661
# Creating Synthetic Forcing for cat-695128
# Creating Synthetic Forcing for cat-695129
# Creating Synthetic Forcing for cat-695756
# Creating Synthetic Forcing for cat-695757
# Creating Synthetic Forcing for cat-697820
# Creating Synthetic Forcing for cat-696445
# Creating Synthetic Forcing for cat-696446
# Creating Synthetic Forcing for cat-697277
# Creating Synthetic Forcing for cat-697278
# Creating Synthetic Forcing for cat-696447
# Creating Synthetic Forcing for cat-697819
# Creating Synthetic Forcing for cat-695758
# Creating Synthetic Forcing for cat-696300
# Creating Synthetic Forcing for cat-697288
# Creating Synthetic Forcing for cat-696301
# Creating Synthetic Forcing for cat-697887
# Creating Synthetic Forcing for cat-695130
# Creating Synthetic Forcing for cat-696959
# Creating Synthetic Forcing for cat-695701
# Creating Synthetic Forcing for cat-695702
# Creating Synthetic Forcing for cat-696456
# Creating Synthetic Forcing for cat-696457
# Creating Synthetic Forcing for cat-696302
# Creating Synthetic Forcing for cat-696653
# Creating Synthetic Forcing for cat-697329
# Creating Synthetic Forcing for cat-695703
# Creating Synthetic Forcing for cat-696938
# Creating Synthetic Forcing for cat-695704
# Creating Synthetic Forcing for cat-695705
# Creating Synthetic Forcing for cat-698618
# Creating Synthetic Forcing for cat-695131
# Creating Synthetic Forcing for cat-696108
# Creating Synthetic Forcing for cat-696109
# Creating Synthetic Forcing for cat-695132
# Creating Synthetic Forcing for cat-697818
# Creating Synthetic Forcing for cat-695133
# Creating Synthetic Forcing for cat-696961
# Creating Synthetic Forcing for cat-696962
# Creating Synthetic Forcing for cat-696963
# Creating Synthetic Forcing for cat-698610
# Creating Synthetic Forcing for cat-695134
# Creating Synthetic Forcing for cat-697817
# Creating Synthetic Forcing for cat-695135
# Creating Synthetic Forcing for cat-695136
# Creating Synthetic Forcing for cat-695137
# Creating Synthetic Forcing for cat-698688
# Creating Synthetic Forcing for cat-695138
# Creating Synthetic Forcing for cat-696218
# Creating Synthetic Forcing for cat-696219
# Creating Synthetic Forcing for cat-697885
# Creating Synthetic Forcing for cat-696220
# Creating Synthetic Forcing for cat-694753
# Creating Synthetic Forcing for cat-696666
# Creating Synthetic Forcing for cat-696667
# Creating Synthetic Forcing for cat-694754
# Creating Synthetic Forcing for cat-697276
# Creating Synthetic Forcing for cat-694755
# Creating Synthetic Forcing for cat-696958
# Creating Synthetic Forcing for cat-695900
# Creating Synthetic Forcing for cat-698680
# Creating Synthetic Forcing for cat-697886
# Creating Synthetic Forcing for cat-695901
# Creating Synthetic Forcing for cat-698681
# Creating Synthetic Forcing for cat-695902
# Creating Synthetic Forcing for cat-697953
# Creating Synthetic Forcing for cat-695903
# Creating Synthetic Forcing for cat-694756
# Creating Synthetic Forcing for cat-697327
# Creating Synthetic Forcing for cat-697275
# Creating Synthetic Forcing for cat-694757
# Creating Synthetic Forcing for cat-695957
# Creating Synthetic Forcing for cat-695958
# Creating Synthetic Forcing for cat-695959
# Creating Synthetic Forcing for cat-695960
# Creating Synthetic Forcing for cat-694758
# Creating Synthetic Forcing for cat-694977
# Creating Synthetic Forcing for cat-698821
# Creating Synthetic Forcing for cat-694978
# Creating Synthetic Forcing for cat-696492
# Creating Synthetic Forcing for cat-694979
# Creating Synthetic Forcing for cat-697975
# Creating Synthetic Forcing for cat-694980
# Creating Synthetic Forcing for cat-697976
# Creating Synthetic Forcing for cat-694981
# Creating Synthetic Forcing for cat-697978
# Creating Synthetic Forcing for cat-697977
# Creating Synthetic Forcing for cat-694982
# Creating Synthetic Forcing for cat-695622
# Creating Synthetic Forcing for cat-698818
# Creating Synthetic Forcing for cat-695623
# Creating Synthetic Forcing for cat-697384
# Creating Synthetic Forcing for cat-695624
# Creating Synthetic Forcing for cat-698820
# Creating Synthetic Forcing for cat-697973
# Creating Synthetic Forcing for cat-698819
# Creating Synthetic Forcing for cat-697012
# Creating Synthetic Forcing for cat-698817
# Creating Synthetic Forcing for cat-695625
# Creating Synthetic Forcing for cat-695626
# Creating Synthetic Forcing for cat-694983
# Creating Synthetic Forcing for cat-697271
# Creating Synthetic Forcing for cat-698823
# Creating Synthetic Forcing for cat-697272
# Creating Synthetic Forcing for cat-697979
# Creating Synthetic Forcing for cat-698822
# Creating Synthetic Forcing for cat-694984
# Creating Synthetic Forcing for cat-697980
# Creating Synthetic Forcing for cat-697972
# Creating Synthetic Forcing for cat-697981
# Creating Synthetic Forcing for cat-694985
# Creating Synthetic Forcing for cat-698608
# Creating Synthetic Forcing for cat-695430
# Creating Synthetic Forcing for cat-697969
# Creating Synthetic Forcing for cat-695431
# Creating Synthetic Forcing for cat-696926
# Creating Synthetic Forcing for cat-698811
# Creating Synthetic Forcing for cat-696927
# Creating Synthetic Forcing for cat-696706
# Creating Synthetic Forcing for cat-695432
# Creating Synthetic Forcing for cat-698810
# Creating Synthetic Forcing for cat-696490
# Creating Synthetic Forcing for cat-697010
# Creating Synthetic Forcing for cat-697011
# Creating Synthetic Forcing for cat-698812
# Creating Synthetic Forcing for cat-695433
# Creating Synthetic Forcing for cat-698813
# Creating Synthetic Forcing for cat-695434
# Creating Synthetic Forcing for cat-697970
# Creating Synthetic Forcing for cat-698814
# Creating Synthetic Forcing for cat-698809
# Creating Synthetic Forcing for cat-695435
# Creating Synthetic Forcing for cat-696705
# Creating Synthetic Forcing for cat-696488
# Creating Synthetic Forcing for cat-696489
# Creating Synthetic Forcing for cat-695436
# Creating Synthetic Forcing for cat-696120
# Creating Synthetic Forcing for cat-697383
# Creating Synthetic Forcing for cat-696121
# Creating Synthetic Forcing for cat-698815
# Creating Synthetic Forcing for cat-696122
# Creating Synthetic Forcing for cat-697971
# Creating Synthetic Forcing for cat-696123
# Creating Synthetic Forcing for cat-697008
# Creating Synthetic Forcing for cat-698807
# Creating Synthetic Forcing for cat-697009
# Creating Synthetic Forcing for cat-696491
# Creating Synthetic Forcing for cat-698808
# Creating Synthetic Forcing for cat-697968
# Creating Synthetic Forcing for cat-695437
# Creating Synthetic Forcing for cat-698816
# Creating Synthetic Forcing for cat-696124
# Creating Synthetic Forcing for cat-697967
# Creating Synthetic Forcing for cat-698806
# Creating Synthetic Forcing for cat-695438
# Creating Synthetic Forcing for cat-698607
# Creating Synthetic Forcing for cat-694986
# Creating Synthetic Forcing for cat-697385
# Creating Synthetic Forcing for cat-696223
# Creating Synthetic Forcing for cat-696224
# Creating Synthetic Forcing for cat-698805
# Creating Synthetic Forcing for cat-697966
# Creating Synthetic Forcing for cat-697006
# Creating Synthetic Forcing for cat-697007
# Creating Synthetic Forcing for cat-697982
# Creating Synthetic Forcing for cat-694987
# Creating Synthetic Forcing for cat-696928
# Creating Synthetic Forcing for cat-698824
# Creating Synthetic Forcing for cat-696929
# Creating Synthetic Forcing for cat-694988
# Creating Synthetic Forcing for cat-695173
# Creating Synthetic Forcing for cat-697989
# Creating Synthetic Forcing for cat-695174
# Creating Synthetic Forcing for cat-696322
# Creating Synthetic Forcing for cat-696323
# Creating Synthetic Forcing for cat-697394
# Creating Synthetic Forcing for cat-696709
# Creating Synthetic Forcing for cat-697392
# Creating Synthetic Forcing for cat-698832
# Creating Synthetic Forcing for cat-697393
# Creating Synthetic Forcing for cat-698831
# Creating Synthetic Forcing for cat-695175
# Creating Synthetic Forcing for cat-696321
# Creating Synthetic Forcing for cat-697395
# Creating Synthetic Forcing for cat-698833
# Creating Synthetic Forcing for cat-695176
# Creating Synthetic Forcing for cat-697396
# Creating Synthetic Forcing for cat-697397
# Creating Synthetic Forcing for cat-697017
# Creating Synthetic Forcing for cat-698830
# Creating Synthetic Forcing for cat-695177
# Creating Synthetic Forcing for cat-695420
# Creating Synthetic Forcing for cat-698827
# Creating Synthetic Forcing for cat-695421
# Creating Synthetic Forcing for cat-697974
# Creating Synthetic Forcing for cat-696707
# Creating Synthetic Forcing for cat-697984
# Creating Synthetic Forcing for cat-695422
# Creating Synthetic Forcing for cat-697015
# Creating Synthetic Forcing for cat-698828
# Creating Synthetic Forcing for cat-695423
# Creating Synthetic Forcing for cat-697387
# Creating Synthetic Forcing for cat-696320
# Creating Synthetic Forcing for cat-697016
# Creating Synthetic Forcing for cat-696708
# Creating Synthetic Forcing for cat-697388
# Creating Synthetic Forcing for cat-695424
# Creating Synthetic Forcing for cat-697985
# Creating Synthetic Forcing for cat-697389
# Creating Synthetic Forcing for cat-696225
# Creating Synthetic Forcing for cat-696226
# Creating Synthetic Forcing for cat-697014
# Creating Synthetic Forcing for cat-697986
# Creating Synthetic Forcing for cat-695425
# Creating Synthetic Forcing for cat-697390
# Creating Synthetic Forcing for cat-695787
# Creating Synthetic Forcing for cat-695788
# Creating Synthetic Forcing for cat-695426
# Creating Synthetic Forcing for cat-697988
# Creating Synthetic Forcing for cat-697391
# Creating Synthetic Forcing for cat-698829
# Creating Synthetic Forcing for cat-697987
# Creating Synthetic Forcing for cat-695178
# Creating Synthetic Forcing for cat-695908
# Creating Synthetic Forcing for cat-697399
# Creating Synthetic Forcing for cat-695909
# Creating Synthetic Forcing for cat-697990
# Creating Synthetic Forcing for cat-698835
# Creating Synthetic Forcing for cat-698834
# Creating Synthetic Forcing for cat-695910
# Creating Synthetic Forcing for cat-697398
# Creating Synthetic Forcing for cat-695179
# Creating Synthetic Forcing for cat-697013
# Creating Synthetic Forcing for cat-696205
# Creating Synthetic Forcing for cat-697983
# Creating Synthetic Forcing for cat-697386
# Creating Synthetic Forcing for cat-698826
# Creating Synthetic Forcing for cat-696206
# Creating Synthetic Forcing for cat-698836
# Creating Synthetic Forcing for cat-698837
# Creating Synthetic Forcing for cat-695180
# Creating Synthetic Forcing for cat-698840
# Creating Synthetic Forcing for cat-698838
# Creating Synthetic Forcing for cat-698825
# Creating Synthetic Forcing for cat-695181
# Creating Synthetic Forcing for cat-696645
# Creating Synthetic Forcing for cat-698839
# Creating Synthetic Forcing for cat-696646
# Creating Synthetic Forcing for cat-697991
# Creating Synthetic Forcing for cat-698606
# Creating Synthetic Forcing for cat-694989
# Creating Synthetic Forcing for cat-694990
# Creating Synthetic Forcing for cat-696443
# Creating Synthetic Forcing for cat-698803
# Creating Synthetic Forcing for cat-696444
# Creating Synthetic Forcing for cat-696704
# Creating Synthetic Forcing for cat-698804
# Creating Synthetic Forcing for cat-697401
# Creating Synthetic Forcing for cat-697400
# Creating Synthetic Forcing for cat-694991
# Creating Synthetic Forcing for cat-697992
# Creating Synthetic Forcing for cat-697965
# Creating Synthetic Forcing for cat-694992
# Creating Synthetic Forcing for cat-695507
# Creating Synthetic Forcing for cat-698843
# Creating Synthetic Forcing for cat-695508
# Creating Synthetic Forcing for cat-698844
# Creating Synthetic Forcing for cat-696442
# Creating Synthetic Forcing for cat-696299
# Creating Synthetic Forcing for cat-697404
# Creating Synthetic Forcing for cat-695509
# Creating Synthetic Forcing for cat-698845
# Creating Synthetic Forcing for cat-695978
# Creating Synthetic Forcing for cat-698847
# Creating Synthetic Forcing for cat-696493
# Creating Synthetic Forcing for cat-698846
# Creating Synthetic Forcing for cat-695979
# Creating Synthetic Forcing for cat-697995
# Creating Synthetic Forcing for cat-697996
# Creating Synthetic Forcing for cat-697407
# Creating Synthetic Forcing for cat-695980
# Creating Synthetic Forcing for cat-697994
# Creating Synthetic Forcing for cat-697403
# Creating Synthetic Forcing for cat-697405
# Creating Synthetic Forcing for cat-697406
# Creating Synthetic Forcing for cat-695510
# Creating Synthetic Forcing for cat-698842
# Creating Synthetic Forcing for cat-697993
# Creating Synthetic Forcing for cat-697402
# Creating Synthetic Forcing for cat-698841
# Creating Synthetic Forcing for cat-695511
# Creating Synthetic Forcing for cat-698848
# Creating Synthetic Forcing for cat-697997
# Creating Synthetic Forcing for cat-697018
# Creating Synthetic Forcing for cat-694993
# Creating Synthetic Forcing for cat-694994
# Creating Synthetic Forcing for cat-695439
# Creating Synthetic Forcing for cat-695440
# Creating Synthetic Forcing for cat-698798
# Creating Synthetic Forcing for cat-696700
# Creating Synthetic Forcing for cat-698797
# Creating Synthetic Forcing for cat-698796
# Creating Synthetic Forcing for cat-695441
# Creating Synthetic Forcing for cat-697962
# Creating Synthetic Forcing for cat-696701
# Creating Synthetic Forcing for cat-698799
# Creating Synthetic Forcing for cat-697003
# Creating Synthetic Forcing for cat-697004
# Creating Synthetic Forcing for cat-696702
# Creating Synthetic Forcing for cat-697274
# Creating Synthetic Forcing for cat-698795
# Creating Synthetic Forcing for cat-695442
# Creating Synthetic Forcing for cat-698800
# Creating Synthetic Forcing for cat-695443
# Creating Synthetic Forcing for cat-696105
# Creating Synthetic Forcing for cat-697963
# Creating Synthetic Forcing for cat-696106
# Creating Synthetic Forcing for cat-698801
# Creating Synthetic Forcing for cat-696107
# Creating Synthetic Forcing for cat-697961
# Creating Synthetic Forcing for cat-696486
# Creating Synthetic Forcing for cat-698794
# Creating Synthetic Forcing for cat-696487
# Creating Synthetic Forcing for cat-698793
# Creating Synthetic Forcing for cat-695444
# Creating Synthetic Forcing for cat-697960
# Creating Synthetic Forcing for cat-695445
# Creating Synthetic Forcing for cat-697005
# Creating Synthetic Forcing for cat-696703
# Creating Synthetic Forcing for cat-697959
# Creating Synthetic Forcing for cat-698802
# Creating Synthetic Forcing for cat-697964
# Creating Synthetic Forcing for cat-698792
# Creating Synthetic Forcing for cat-695446
# Creating Synthetic Forcing for cat-695447
# Creating Synthetic Forcing for cat-695976
# Creating Synthetic Forcing for cat-698791
# Creating Synthetic Forcing for cat-695977
# Creating Synthetic Forcing for cat-694995
# Creating Synthetic Forcing for cat-697958
# Creating Synthetic Forcing for cat-694996
# Creating Synthetic Forcing for cat-697002
# Creating Synthetic Forcing for cat-694997
# Creating Synthetic Forcing for cat-697808
# Creating Synthetic Forcing for cat-695139
# Creating Synthetic Forcing for cat-698597
# Creating Synthetic Forcing for cat-695140
# Creating Synthetic Forcing for cat-696203
# Creating Synthetic Forcing for cat-696922
# Creating Synthetic Forcing for cat-696204
# Creating Synthetic Forcing for cat-697809
# Creating Synthetic Forcing for cat-695141
# Creating Synthetic Forcing for cat-697810
# Creating Synthetic Forcing for cat-695142
# Creating Synthetic Forcing for cat-698598
# Creating Synthetic Forcing for cat-698599
# Creating Synthetic Forcing for cat-695143
# Creating Synthetic Forcing for cat-696923
# Creating Synthetic Forcing for cat-695144
# Creating Synthetic Forcing for cat-696296
# Creating Synthetic Forcing for cat-697805
# Creating Synthetic Forcing for cat-696297
# Creating Synthetic Forcing for cat-697804
# Creating Synthetic Forcing for cat-696015
# Creating Synthetic Forcing for cat-696641
# Creating Synthetic Forcing for cat-698596
# Creating Synthetic Forcing for cat-696642
# Creating Synthetic Forcing for cat-696710
# Creating Synthetic Forcing for cat-697806
# Creating Synthetic Forcing for cat-696016
# Creating Synthetic Forcing for cat-697807
# Creating Synthetic Forcing for cat-695145
# Creating Synthetic Forcing for cat-697998
# Creating Synthetic Forcing for cat-698849
# Creating Synthetic Forcing for cat-697999
# Creating Synthetic Forcing for cat-696324
# Creating Synthetic Forcing for cat-696325
# Creating Synthetic Forcing for cat-696494
# Creating Synthetic Forcing for cat-696495
# Creating Synthetic Forcing for cat-698000
# Creating Synthetic Forcing for cat-697019
# Creating Synthetic Forcing for cat-695146
# Creating Synthetic Forcing for cat-698600
# Creating Synthetic Forcing for cat-695382
# Creating Synthetic Forcing for cat-697811
# Creating Synthetic Forcing for cat-698601
# Creating Synthetic Forcing for cat-695383
# Creating Synthetic Forcing for cat-695419
# Creating Synthetic Forcing for cat-695384
# Creating Synthetic Forcing for cat-695744
# Creating Synthetic Forcing for cat-697269
# Creating Synthetic Forcing for cat-695745
# Creating Synthetic Forcing for cat-696924
# Creating Synthetic Forcing for cat-697812
# Creating Synthetic Forcing for cat-695746
# Creating Synthetic Forcing for cat-697273
# Creating Synthetic Forcing for cat-695747
# Creating Synthetic Forcing for cat-697408
# Creating Synthetic Forcing for cat-697409
# Creating Synthetic Forcing for cat-696643
# Creating Synthetic Forcing for cat-695147
# Creating Synthetic Forcing for cat-694998
# Creating Synthetic Forcing for cat-698602
# Creating Synthetic Forcing for cat-696644
# Creating Synthetic Forcing for cat-694999
# Creating Synthetic Forcing for cat-697813
# Creating Synthetic Forcing for cat-698604
# Creating Synthetic Forcing for cat-695000
# Creating Synthetic Forcing for cat-695904
# Creating Synthetic Forcing for cat-697957
# Creating Synthetic Forcing for cat-695905
# Creating Synthetic Forcing for cat-698790
# Creating Synthetic Forcing for cat-695906
# Creating Synthetic Forcing for cat-695907
# Creating Synthetic Forcing for cat-698603
# Creating Synthetic Forcing for cat-696925
# Creating Synthetic Forcing for cat-695001
# Creating Synthetic Forcing for cat-697270
# Creating Synthetic Forcing for cat-697956
# Creating Synthetic Forcing for cat-697814
# Creating Synthetic Forcing for cat-695002
# Creating Synthetic Forcing for cat-696316
# Creating Synthetic Forcing for cat-696317
# Creating Synthetic Forcing for cat-697381
# Creating Synthetic Forcing for cat-696318
# Creating Synthetic Forcing for cat-697382
# Creating Synthetic Forcing for cat-696319
# Creating Synthetic Forcing for cat-695003
# Creating Synthetic Forcing for cat-696998
# Creating Synthetic Forcing for cat-695837
# Creating Synthetic Forcing for cat-698789
# Creating Synthetic Forcing for cat-695838
# Creating Synthetic Forcing for cat-696999
# Creating Synthetic Forcing for cat-698788
# Creating Synthetic Forcing for cat-695839
# Creating Synthetic Forcing for cat-697000
# Creating Synthetic Forcing for cat-697001
# Creating Synthetic Forcing for cat-697955
# Creating Synthetic Forcing for cat-697816
# Creating Synthetic Forcing for cat-697815
# Creating Synthetic Forcing for cat-695004
# Creating Synthetic Forcing for cat-695005
# Creating Synthetic Forcing for cat-696017
# Creating Synthetic Forcing for cat-698605
# Creating Synthetic Forcing for cat-696018
# Creating Synthetic Forcing for cat-696440
# Creating Synthetic Forcing for cat-696441
# Creating Synthetic Forcing for cat-696298
# Creating Synthetic Forcing for cat-696019
# Creating Synthetic Forcing for cat-695006
# Creating Synthetic Forcing for cat-697954
# Creating Synthetic Forcing for cat-697380
# Creating Synthetic Forcing for cat-695007
# Creating Synthetic Forcing for cat-695008
# Creating Synthetic Forcing for cat-694759
# Creating Synthetic Forcing for cat-698744
# Creating Synthetic Forcing for cat-696981
# Creating Synthetic Forcing for cat-694760
# Creating Synthetic Forcing for cat-697374
# Creating Synthetic Forcing for cat-698772
# Creating Synthetic Forcing for cat-697375
# Creating Synthetic Forcing for cat-694761
# Creating Synthetic Forcing for cat-696992
# Creating Synthetic Forcing for cat-696993
# Creating Synthetic Forcing for cat-697925
# Creating Synthetic Forcing for cat-697926
# Creating Synthetic Forcing for cat-694762
# Creating Synthetic Forcing for cat-697371
# Creating Synthetic Forcing for cat-694763
# Creating Synthetic Forcing for cat-694764
# Creating Synthetic Forcing for cat-694765
# Creating Synthetic Forcing for cat-697376
# Creating Synthetic Forcing for cat-694766
# Creating Synthetic Forcing for cat-694767
# Creating Synthetic Forcing for cat-694768
# Creating Synthetic Forcing for cat-694769
# Creating Synthetic Forcing for cat-698759
# Creating Synthetic Forcing for cat-696969
# Creating Synthetic Forcing for cat-696970
# Creating Synthetic Forcing for cat-694770
# Creating Synthetic Forcing for cat-696037
# Creating Synthetic Forcing for cat-696038
# Creating Synthetic Forcing for cat-698745
# Creating Synthetic Forcing for cat-696039
# Creating Synthetic Forcing for cat-698771
# Creating Synthetic Forcing for cat-698773
# Creating Synthetic Forcing for cat-696040
# Creating Synthetic Forcing for cat-696041
# Creating Synthetic Forcing for cat-698775
# Creating Synthetic Forcing for cat-696042
# Creating Synthetic Forcing for cat-698782
# Creating Synthetic Forcing for cat-696043
# Creating Synthetic Forcing for cat-694771
# Creating Synthetic Forcing for cat-696979
# Creating Synthetic Forcing for cat-698743
# Creating Synthetic Forcing for cat-696980
# Creating Synthetic Forcing for cat-698774
# Creating Synthetic Forcing for cat-694772
# Creating Synthetic Forcing for cat-697356
# Creating Synthetic Forcing for cat-694773
# Creating Synthetic Forcing for cat-697943
# Creating Synthetic Forcing for cat-697944
# Creating Synthetic Forcing for cat-697927
# Creating Synthetic Forcing for cat-694774
# Creating Synthetic Forcing for cat-697353
# Creating Synthetic Forcing for cat-695385
# Creating Synthetic Forcing for cat-695386
# Creating Synthetic Forcing for cat-695387
# Creating Synthetic Forcing for cat-697369
# Creating Synthetic Forcing for cat-697370
# Creating Synthetic Forcing for cat-697951
# Creating Synthetic Forcing for cat-697952
# Creating Synthetic Forcing for cat-698785
# Creating Synthetic Forcing for cat-698786
# Creating Synthetic Forcing for cat-695388
# Creating Synthetic Forcing for cat-697354
# Creating Synthetic Forcing for cat-697355
# Creating Synthetic Forcing for cat-697922
# Creating Synthetic Forcing for cat-695389
# Creating Synthetic Forcing for cat-698760
# Creating Synthetic Forcing for cat-698738
# Creating Synthetic Forcing for cat-695390
# Creating Synthetic Forcing for cat-696221
# Creating Synthetic Forcing for cat-696222
# Creating Synthetic Forcing for cat-696976
# Creating Synthetic Forcing for cat-696308
# Creating Synthetic Forcing for cat-697923
# Creating Synthetic Forcing for cat-696309
# Creating Synthetic Forcing for cat-698739
# Creating Synthetic Forcing for cat-696310
# Creating Synthetic Forcing for cat-697938
# Creating Synthetic Forcing for cat-697939
# Creating Synthetic Forcing for cat-697940
# Creating Synthetic Forcing for cat-695391
# Creating Synthetic Forcing for cat-695392
# Creating Synthetic Forcing for cat-698740
# Creating Synthetic Forcing for cat-695393
# Creating Synthetic Forcing for cat-697920
# Creating Synthetic Forcing for cat-698737
# Creating Synthetic Forcing for cat-697921
# Creating Synthetic Forcing for cat-695394
# Creating Synthetic Forcing for cat-698765
# Creating Synthetic Forcing for cat-695395
# Creating Synthetic Forcing for cat-697351
# Creating Synthetic Forcing for cat-698736
# Creating Synthetic Forcing for cat-697352
# Creating Synthetic Forcing for cat-698766
# Creating Synthetic Forcing for cat-695396
# Creating Synthetic Forcing for cat-698741
# Creating Synthetic Forcing for cat-695397
# Creating Synthetic Forcing for cat-698769
# Creating Synthetic Forcing for cat-695398
# Creating Synthetic Forcing for cat-698735
# Creating Synthetic Forcing for cat-695399
# Creating Synthetic Forcing for cat-696311
# Creating Synthetic Forcing for cat-698733
# Creating Synthetic Forcing for cat-696312
# Creating Synthetic Forcing for cat-696986
# Creating Synthetic Forcing for cat-696987
# Creating Synthetic Forcing for cat-696988
# Creating Synthetic Forcing for cat-697919
# Creating Synthetic Forcing for cat-696313
# Creating Synthetic Forcing for cat-698767
# Creating Synthetic Forcing for cat-696314
# Creating Synthetic Forcing for cat-698784
# Creating Synthetic Forcing for cat-696686
# Creating Synthetic Forcing for cat-696687
# Creating Synthetic Forcing for cat-698734
# Creating Synthetic Forcing for cat-696688
# Creating Synthetic Forcing for cat-698783
# Creating Synthetic Forcing for cat-698779
# Creating Synthetic Forcing for cat-696689
# Creating Synthetic Forcing for cat-696315
# Creating Synthetic Forcing for cat-695400
# Creating Synthetic Forcing for cat-696995
# Creating Synthetic Forcing for cat-696996
# Creating Synthetic Forcing for cat-696997
# Creating Synthetic Forcing for cat-695401
# Creating Synthetic Forcing for cat-696977
# Creating Synthetic Forcing for cat-696978
# Creating Synthetic Forcing for cat-695402
# Creating Synthetic Forcing for cat-698732
# Creating Synthetic Forcing for cat-695403
# Creating Synthetic Forcing for cat-698742
# Creating Synthetic Forcing for cat-697924
# Creating Synthetic Forcing for cat-695404
# Creating Synthetic Forcing for cat-698730
# Creating Synthetic Forcing for cat-698731
# Creating Synthetic Forcing for cat-695405
# Creating Synthetic Forcing for cat-695406
# Creating Synthetic Forcing for cat-694775
# Creating Synthetic Forcing for cat-695457
# Creating Synthetic Forcing for cat-695458
# Creating Synthetic Forcing for cat-697359
# Creating Synthetic Forcing for cat-695459
# Creating Synthetic Forcing for cat-698752
# Creating Synthetic Forcing for cat-695460
# Creating Synthetic Forcing for cat-698753
# Creating Synthetic Forcing for cat-698751
# ...
# Creating Synthetic Forcing for cat-698027
# Creating Synthetic Forcing for cat-696348
# Creating Synthetic Forcing for cat-698026
# Creating Synthetic Forcing for cat-695763
# Creating Synthetic Forcing for cat-696513
# Creating Synthetic Forcing for cat-696349
# Creating Synthetic Forcing for cat-695914
# Creating Synthetic Forcing for cat-697039
# Creating Synthetic Forcing for cat-698039
# Creating Synthetic Forcing for cat-695222
# Creating Synthetic Forcing for cat-698040
# Creating Synthetic Forcing for cat-695843
# Creating Synthetic Forcing for cat-696514
# Creating Synthetic Forcing for cat-697450
# Creating Synthetic Forcing for cat-698022
# Creating Synthetic Forcing for cat-695223
# Creating Synthetic Forcing for cat-696515
# Creating Synthetic Forcing for cat-695674
# Creating Synthetic Forcing for cat-696725
# Creating Synthetic Forcing for cat-696350
# Creating Synthetic Forcing for cat-695675
# Creating Synthetic Forcing for cat-697043
# Creating Synthetic Forcing for cat-696726
# Creating Synthetic Forcing for cat-695224
# Creating Synthetic Forcing for cat-695225
# Creating Synthetic Forcing for cat-694836
# Creating Synthetic Forcing for cat-698071
# Creating Synthetic Forcing for cat-695148
# Creating Synthetic Forcing for cat-696520
# Creating Synthetic Forcing for cat-698072
# Creating Synthetic Forcing for cat-698073
# Creating Synthetic Forcing for cat-695149
# Creating Synthetic Forcing for cat-697067
# Creating Synthetic Forcing for cat-695150
# Creating Synthetic Forcing for cat-696739
# Creating Synthetic Forcing for cat-695151
# Creating Synthetic Forcing for cat-697465
# Creating Synthetic Forcing for cat-698074
# Creating Synthetic Forcing for cat-698020
# Creating Synthetic Forcing for cat-695152
# Creating Synthetic Forcing for cat-696738
# Creating Synthetic Forcing for cat-696740
# Creating Synthetic Forcing for cat-697064
# Creating Synthetic Forcing for cat-698075
# Creating Synthetic Forcing for cat-695153
# Creating Synthetic Forcing for cat-695770
# Creating Synthetic Forcing for cat-697464
# Creating Synthetic Forcing for cat-695771
# Creating Synthetic Forcing for cat-697063
# Creating Synthetic Forcing for cat-698069
# Creating Synthetic Forcing for cat-695772
# Creating Synthetic Forcing for cat-695773
# Creating Synthetic Forcing for cat-698068
# Creating Synthetic Forcing for cat-698070
# Creating Synthetic Forcing for cat-695774
# Creating Synthetic Forcing for cat-695775
# Creating Synthetic Forcing for cat-697466
# Creating Synthetic Forcing for cat-695154
# Creating Synthetic Forcing for cat-697062
# Creating Synthetic Forcing for cat-698076
# Creating Synthetic Forcing for cat-695155
# Creating Synthetic Forcing for cat-695844
# Creating Synthetic Forcing for cat-695845
# Creating Synthetic Forcing for cat-698079
# Creating Synthetic Forcing for cat-696155
# Creating Synthetic Forcing for cat-696154
# Creating Synthetic Forcing for cat-698077
# Creating Synthetic Forcing for cat-698078
# Creating Synthetic Forcing for cat-695156
# Creating Synthetic Forcing for cat-696153
# Creating Synthetic Forcing for cat-695768
# Creating Synthetic Forcing for cat-695769
# Creating Synthetic Forcing for cat-696737
# Creating Synthetic Forcing for cat-696357
# Creating Synthetic Forcing for cat-696519
# Creating Synthetic Forcing for cat-697061
# Creating Synthetic Forcing for cat-698080
# Creating Synthetic Forcing for cat-695157
# Creating Synthetic Forcing for cat-698081
# Creating Synthetic Forcing for cat-695158
# Creating Synthetic Forcing for cat-696139
# Creating Synthetic Forcing for cat-697065
# Creating Synthetic Forcing for cat-696140
# Creating Synthetic Forcing for cat-697443
# Creating Synthetic Forcing for cat-696144
# Creating Synthetic Forcing for cat-696521
# Creating Synthetic Forcing for cat-696741
# Creating Synthetic Forcing for cat-696522
# Creating Synthetic Forcing for cat-696511
# Creating Synthetic Forcing for cat-694837
# Creating Synthetic Forcing for cat-695989
# Creating Synthetic Forcing for cat-696241
# Creating Synthetic Forcing for cat-698021
# Creating Synthetic Forcing for cat-697037
# Creating Synthetic Forcing for cat-695990
# Creating Synthetic Forcing for cat-696512
# Creating Synthetic Forcing for cat-697441
# Creating Synthetic Forcing for cat-697066
# Creating Synthetic Forcing for cat-696742
# Creating Synthetic Forcing for cat-694838
# Creating Synthetic Forcing for cat-696142
# Creating Synthetic Forcing for cat-697442
# Creating Synthetic Forcing for cat-696143
# Creating Synthetic Forcing for cat-695991
# Creating Synthetic Forcing for cat-697467
# Creating Synthetic Forcing for cat-697036
# Creating Synthetic Forcing for cat-694839
# Creating Synthetic Forcing for cat-695568
# Creating Synthetic Forcing for cat-695569
# Creating Synthetic Forcing for cat-696358
# Creating Synthetic Forcing for cat-697468
# Creating Synthetic Forcing for cat-695570
# Creating Synthetic Forcing for cat-695916
# Creating Synthetic Forcing for cat-698082
# Creating Synthetic Forcing for cat-695917
# Creating Synthetic Forcing for cat-696743
# Creating Synthetic Forcing for cat-698083
# Creating Synthetic Forcing for cat-695571
# Creating Synthetic Forcing for cat-695992
# Creating Synthetic Forcing for cat-694840
# Creating Synthetic Forcing for cat-697431
# Creating Synthetic Forcing for cat-695517
# Creating Synthetic Forcing for cat-697433
# Creating Synthetic Forcing for cat-697432
# Creating Synthetic Forcing for cat-695518
# Creating Synthetic Forcing for cat-696133
# Creating Synthetic Forcing for cat-697030
# Creating Synthetic Forcing for cat-696134
# Creating Synthetic Forcing for cat-696343
# Creating Synthetic Forcing for cat-696344
# Creating Synthetic Forcing for cat-697434
# Creating Synthetic Forcing for cat-695519
# Creating Synthetic Forcing for cat-697031
# Creating Synthetic Forcing for cat-695911
# Creating Synthetic Forcing for cat-697435
# Creating Synthetic Forcing for cat-695520
# Creating Synthetic Forcing for cat-695559
# Creating Synthetic Forcing for cat-696240
# Creating Synthetic Forcing for cat-695560
# Creating Synthetic Forcing for cat-696239
# Creating Synthetic Forcing for cat-696506
# Creating Synthetic Forcing for cat-695561
# Creating Synthetic Forcing for cat-696135
# Creating Synthetic Forcing for cat-696498
# Creating Synthetic Forcing for cat-697430
# Creating Synthetic Forcing for cat-698015
# Creating Synthetic Forcing for cat-695521
# Creating Synthetic Forcing for cat-695522
# Creating Synthetic Forcing for cat-697410
# Creating Synthetic Forcing for cat-696048
# Creating Synthetic Forcing for cat-696497
# Creating Synthetic Forcing for cat-694841
# Creating Synthetic Forcing for cat-695988
# Creating Synthetic Forcing for cat-694842
# Creating Synthetic Forcing for cat-696340
# Creating Synthetic Forcing for cat-696341
# Creating Synthetic Forcing for cat-697411
# Creating Synthetic Forcing for cat-694843
# Creating Synthetic Forcing for cat-695557
# Creating Synthetic Forcing for cat-697429
# Creating Synthetic Forcing for cat-695558
# Creating Synthetic Forcing for cat-695596
# Creating Synthetic Forcing for cat-696227
# Creating Synthetic Forcing for cat-695597
# Creating Synthetic Forcing for cat-696125
# Creating Synthetic Forcing for cat-697438
# Creating Synthetic Forcing for cat-696126
# Creating Synthetic Forcing for cat-695598
# Creating Synthetic Forcing for cat-695599
# Creating Synthetic Forcing for cat-698016
# Creating Synthetic Forcing for cat-696718
# Creating Synthetic Forcing for cat-695627
# Creating Synthetic Forcing for cat-695628
# Creating Synthetic Forcing for cat-696049
# Creating Synthetic Forcing for cat-697436
# Creating Synthetic Forcing for cat-697437
# Creating Synthetic Forcing for cat-695629
# Creating Synthetic Forcing for cat-697428
# Creating Synthetic Forcing for cat-694844
# Creating Synthetic Forcing for cat-696132
# Creating Synthetic Forcing for cat-694845
# Creating Synthetic Forcing for cat-697420
# Creating Synthetic Forcing for cat-695044
# Creating Synthetic Forcing for cat-696509
# Creating Synthetic Forcing for cat-698006
# Creating Synthetic Forcing for cat-696510
# Creating Synthetic Forcing for cat-696716
# Creating Synthetic Forcing for cat-695045
# Creating Synthetic Forcing for cat-696342
# Creating Synthetic Forcing for cat-695912
# Creating Synthetic Forcing for cat-695913
# Creating Synthetic Forcing for cat-698005
# Creating Synthetic Forcing for cat-696138
# Creating Synthetic Forcing for cat-696233
# Creating Synthetic Forcing for cat-697419
# Creating Synthetic Forcing for cat-696234
# Creating Synthetic Forcing for cat-698007
# Creating Synthetic Forcing for cat-695046
# Creating Synthetic Forcing for cat-695841
# Creating Synthetic Forcing for cat-698009
# Creating Synthetic Forcing for cat-695842
# Creating Synthetic Forcing for cat-698008
# Creating Synthetic Forcing for cat-695047
# Creating Synthetic Forcing for cat-695671
# Creating Synthetic Forcing for cat-696228
# Creating Synthetic Forcing for cat-697020
# Creating Synthetic Forcing for cat-695048
# Creating Synthetic Forcing for cat-696711
# Creating Synthetic Forcing for cat-696050
# Creating Synthetic Forcing for cat-697417
# Creating Synthetic Forcing for cat-697418
# Creating Synthetic Forcing for cat-698010
# Creating Synthetic Forcing for cat-695049
# Creating Synthetic Forcing for cat-696235
# Creating Synthetic Forcing for cat-696130
# Creating Synthetic Forcing for cat-695050
# Creating Synthetic Forcing for cat-698013
# Creating Synthetic Forcing for cat-697027
# Creating Synthetic Forcing for cat-695191
# Creating Synthetic Forcing for cat-696047
# Creating Synthetic Forcing for cat-696335
# Creating Synthetic Forcing for cat-695192
# Creating Synthetic Forcing for cat-695982
# Creating Synthetic Forcing for cat-695983
# Creating Synthetic Forcing for cat-695984
# Creating Synthetic Forcing for cat-697423
# Creating Synthetic Forcing for cat-695193
# Creating Synthetic Forcing for cat-695672
# Creating Synthetic Forcing for cat-695673
# Creating Synthetic Forcing for cat-696336
# Creating Synthetic Forcing for cat-698012
# Creating Synthetic Forcing for cat-695194
# Creating Synthetic Forcing for cat-697422
# Creating Synthetic Forcing for cat-695255
# Creating Synthetic Forcing for cat-696334
# Creating Synthetic Forcing for cat-698011
# Creating Synthetic Forcing for cat-695256
# Creating Synthetic Forcing for cat-695257
# Creating Synthetic Forcing for cat-696131
# Creating Synthetic Forcing for cat-696504
# Creating Synthetic Forcing for cat-697421
# Creating Synthetic Forcing for cat-695195
# Creating Synthetic Forcing for cat-696337
# Creating Synthetic Forcing for cat-695196
# Creating Synthetic Forcing for cat-695051
# Creating Synthetic Forcing for cat-695052
# Creating Synthetic Forcing for cat-697416
# Creating Synthetic Forcing for cat-695538
# Creating Synthetic Forcing for cat-695981
# Creating Synthetic Forcing for cat-696232
# Creating Synthetic Forcing for cat-695539
# Creating Synthetic Forcing for cat-696502
# Creating Synthetic Forcing for cat-695540
# Creating Synthetic Forcing for cat-696231
# Creating Synthetic Forcing for cat-696503
# Creating Synthetic Forcing for cat-697424
# Creating Synthetic Forcing for cat-695053
# Creating Synthetic Forcing for cat-697026
# Creating Synthetic Forcing for cat-695407
# Creating Synthetic Forcing for cat-697025
# Creating Synthetic Forcing for cat-698004
# Creating Synthetic Forcing for cat-695408
# Creating Synthetic Forcing for cat-697415
# Creating Synthetic Forcing for cat-697024
# Creating Synthetic Forcing for cat-695409
# Creating Synthetic Forcing for cat-696326
# Creating Synthetic Forcing for cat-697414
# Creating Synthetic Forcing for cat-696333
# Creating Synthetic Forcing for cat-695410
# Creating Synthetic Forcing for cat-695411
# Creating Synthetic Forcing for cat-695412
# Creating Synthetic Forcing for cat-696496
# Creating Synthetic Forcing for cat-695448
# Creating Synthetic Forcing for cat-696715
# Creating Synthetic Forcing for cat-695449
# Creating Synthetic Forcing for cat-696332
# Creating Synthetic Forcing for cat-695450
# Creating Synthetic Forcing for cat-695711
# Creating Synthetic Forcing for cat-695600
# Creating Synthetic Forcing for cat-696046
# Creating Synthetic Forcing for cat-696338
# Creating Synthetic Forcing for cat-695054
# Creating Synthetic Forcing for cat-696720
# Creating Synthetic Forcing for cat-695601
# Creating Synthetic Forcing for cat-698014
# Creating Synthetic Forcing for cat-695602
# Creating Synthetic Forcing for cat-696237
# Creating Synthetic Forcing for cat-695603
# Creating Synthetic Forcing for cat-696717
# Creating Synthetic Forcing for cat-695840
# Creating Synthetic Forcing for cat-697028
# Creating Synthetic Forcing for cat-696044
# Creating Synthetic Forcing for cat-696236
# Creating Synthetic Forcing for cat-695604
# Creating Synthetic Forcing for cat-695605
# Creating Synthetic Forcing for cat-698003
# Creating Synthetic Forcing for cat-695643
# Creating Synthetic Forcing for cat-696714
# Creating Synthetic Forcing for cat-696501
# Creating Synthetic Forcing for cat-696230
# Creating Synthetic Forcing for cat-697413
# Creating Synthetic Forcing for cat-695644
# Creating Synthetic Forcing for cat-696238
# Creating Synthetic Forcing for cat-695055
# Creating Synthetic Forcing for cat-696505
# Creating Synthetic Forcing for cat-695985
# Creating Synthetic Forcing for cat-695986
# Creating Synthetic Forcing for cat-695987
# Creating Synthetic Forcing for cat-698002
# Creating Synthetic Forcing for cat-696713
# Creating Synthetic Forcing for cat-696129
# Creating Synthetic Forcing for cat-696229
# Creating Synthetic Forcing for cat-696500
# Creating Synthetic Forcing for cat-697029
# Creating Synthetic Forcing for cat-697426
# Creating Synthetic Forcing for cat-697425
# Creating Synthetic Forcing for cat-695056
# Creating Synthetic Forcing for cat-696339
# Creating Synthetic Forcing for cat-695057
# Creating Synthetic Forcing for cat-696045
# Creating Synthetic Forcing for cat-697427
# Creating Synthetic Forcing for cat-695058
# Creating Synthetic Forcing for cat-694846
# Creating Synthetic Forcing for cat-696127
# Creating Synthetic Forcing for cat-696128
# Creating Synthetic Forcing for cat-696712
# Creating Synthetic Forcing for cat-696499
# Creating Synthetic Forcing for cat-694847
# Creating Synthetic Forcing for cat-697032
# Creating Synthetic Forcing for cat-694848
# Creating Synthetic Forcing for cat-695554
# Creating Synthetic Forcing for cat-697023
# Creating Synthetic Forcing for cat-695555
# Creating Synthetic Forcing for cat-697412
# Creating Synthetic Forcing for cat-695556
# Creating Synthetic Forcing for cat-694849
# Creating Synthetic Forcing for cat-696508
# Creating Synthetic Forcing for cat-697022
# Creating Synthetic Forcing for cat-694850
# Creating Synthetic Forcing for cat-697439
# Creating Synthetic Forcing for cat-696136
# Creating Synthetic Forcing for cat-696507
# Creating Synthetic Forcing for cat-696137
# Creating Synthetic Forcing for cat-698018
# Creating Synthetic Forcing for cat-698017
# Creating Synthetic Forcing for cat-696719
# Creating Synthetic Forcing for cat-697021
# Creating Synthetic Forcing for cat-697033
# Creating Synthetic Forcing for cat-694851
# Creating Synthetic Forcing for cat-696327
# Creating Synthetic Forcing for cat-696328
# Creating Synthetic Forcing for cat-698001
# Creating Synthetic Forcing for cat-696329
# Creating Synthetic Forcing for cat-696330
# Creating Synthetic Forcing for cat-696331
# Creating Synthetic Forcing for cat-694852
# Processing of wb-694854 watershed is done!
# Preparation of geometries for wb-694723 watershed is done!
# The dataset contains 2 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694723 watershed is done!
# The dataset contains 169 timesteps
# Frozen({'y': (5,), 'x': (1,), 'time': (169,)})
# Computation of basin-averaged forcing data for wb-694723 watershed is done!
#   0%|          | 0/2 [00:00<?, ?it/s]
# 2
# 2
# The shape of 'gdf' and the length of 'results' are equal.
# Processing of wb-694723 watershed is done!
# Preparation of geometries for wb-694722 watershed is done!
# The dataset contains 1 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694722 watershed is done!
# The dataset contains 169 timesteps
# Frozen({'y': (2,), 'x': (1,), 'time': (169,)})
# Computation of basin-averaged forcing data for wb-694722 watershed is done!
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1
# 1
# The shape of 'gdf' and the length of 'results' are equal.
# Processing of wb-694722 watershed is done!

# %% [markdown]
# ## Plot all watersheds

# %%
# List of watersheds in NYC area
ids_list = ['wb-694856', 'wb-694725', 'wb-694855', 'wb-694724',  'wb-694854', 'wb-694723', 'wb-698891', 'wb-694722']

# Create a figure with 8 subplots, with 2 rows and 4 columns
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(20, 14))

# Flatten the axes array so we can easily loop over it
axs = axs.flatten()

for ax, wb_id in zip(axs, tqdm(ids_list)):
    
    ################################################################
    ### Add spatial reference to the model domain 
    ################################################################
    
    # prepare geometries for spatial averaging
    gdf = geopandas.read_file(f'{wb_id}/config/{wb_id.split("_")[0]}_upstream_subset.gpkg', layer='divides')

    # convert these data into the projection of our forcing data
    target_crs = pyproj.Proj(proj='lcc',
                           lat_1=30.,
                           lat_2=60., 
                           lat_0=40.0000076293945, lon_0=-97., # Center point
                           a=6370000, b=6370000) 

    gdf = gdf.to_crs(target_crs.crs)
    
    # important step
    # rechunk the dataset to solve the memory limit issue
    ds = ds.chunk(chunks={'time':1})
    
    print(f"Preparation of geometries for {wb_id} watershed is done!")
    
    #################################################################
    ### Clip AORC to the extent of the subset hydrofabric geometries
    #################################################################
    
    # create zonal id column
    gdf['cat'] = gdf.id.str.split('-').str[-1].astype(int)

    # clip AORC to the extent of the hydrofabric geometries
    ds = ds.rio.clip(gdf.geometry.values,
                     gdf.crs,
                     drop=True,
                     invert=False)

    # select a single array of data to use as a template
    # lwdown_data = ds.isel(time=0).LWDOWN

    # create a grid for the geocube
    out_grid = make_geocube(
        vector_data=gdf,
        measurements=["cat"],
        like=ds # ensure the data are on the same grid
    )

    # add the catchment variable to the original dataset
    ds = ds.assign_coords(cat = (['y','x'], out_grid.cat.data))

    # compute the unique catchment IDs which will be used to compute zonal statistics
    catchment_ids = numpy.unique(ds.cat.data[~numpy.isnan(ds.cat.data)])

    print(f'The dataset contains {len(catchment_ids)} catchments')
    
    print(f"Clipping AORC to the extent of the subset hydrofabric geometries for {wb_id} watershed is done!")

    ######################################################################
    ### Preview the gridded catchments over the watershed vector boundary
    ######################################################################
    
    # plot the gridded catchment mapping
    ds.cat.plot(ax=ax)

    # preview map geometries
    gdf.iloc[:].plot(ax=ax, linewidth=0.8, edgecolor='k', facecolor='None')

    # Remove axes labels
    ax.set_xlabel('')
    ax.set_ylabel('')

    # Remove all spines
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

    ax.set_title(f"{wb_id}", fontsize=20, y=1.03)

# Adjust the height of the colorbar to 80%
cbar = plt.colorbar(ax=axs.ravel().tolist(), pad=0.01, fraction=0.8)
cbar.set_label('Catchment ID', rotation=270)

# Save the figure as a PNG
plt.savefig('watersheds.png', dpi=300)

plt.show()
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Preparation of geometries for wb-694856 watershed is done!
# The dataset contains 4068 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694856 watershed is done!
# Preparation of geometries for wb-694725 watershed is done!
# The dataset contains 4 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694725 watershed is done!
# Preparation of geometries for wb-694855 watershed is done!
# The dataset contains 4 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694855 watershed is done!
# Preparation of geometries for wb-694724 watershed is done!
# The dataset contains 3 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694724 watershed is done!
# Preparation of geometries for wb-694854 watershed is done!
# The dataset contains 2 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694854 watershed is done!
# Preparation of geometries for wb-694723 watershed is done!
# The dataset contains 2 catchments
# Clipping AORC to the extent of the subset hydrofabric geometries for wb-694723 watershed is done!
# Preparation of geometries for wb-698891 watershed is done!
# ---------------------------------------------------------------------------
# NoDataInBounds                            Traceback (most recent call last)
# Cell In[16], line 42
#      39 gdf['cat'] = gdf.id.str.split('-').str[-1].astype(int)
#      41 # clip AORC to the extent of the hydrofabric geometries
# ---> 42 ds = ds.rio.clip(gdf.geometry.values,
#      43                  gdf.crs,
#      44                  drop=True,
#      45                  invert=False)
#      47 # select a single array of data to use as a template
#      48 # lwdown_data = ds.isel(time=0).LWDOWN
#      49
#      50 # create a grid for the geocube
#      51 out_grid = make_geocube(
#      52     vector_data=gdf,
#      53     measurements=["cat"],
#      54     like=ds # ensure the data are on the same grid
#      55 )
#
# File /opt/conda/lib/python3.9/site-packages/rioxarray/raster_dataset.py:381, in RasterDataset.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     378 try:
#     379     x_dim, y_dim = _get_spatial_dims(self._obj, var)
#     380     clipped_dataset[var] = (
# --> 381         self._obj[var]
#     382         .rio.set_spatial_dims(x_dim=x_dim, y_dim=y_dim, inplace=True)
#     383         .rio.clip(
#     384             geometries,
#     385             crs=crs,
#     386             all_touched=all_touched,
#     387             drop=drop,
#     388             invert=invert,
#     389             from_disk=from_disk,
#     390         )
#     391     )
#     392 except MissingSpatialDimensionError:
#     393     if len(self._obj[var].dims) >= 2 and not get_option(
#     394         SKIP_MISSING_SPATIAL_DIMS
#     395     ):
#
# File /opt/conda/lib/python3.9/site-packages/rioxarray/raster_array.py:917, in RasterArray.clip(self, geometries, crs, all_touched, drop, invert, from_disk)
#     905     cropped_ds = _clip_xarray(
#     906         self._obj,
#     907         geometries=geometries,
#    (...)
#     910         invert=invert,
#     911     )
#     913 if (
#     914     cropped_ds.coords[self.x_dim].size < 1
#     915     or cropped_ds.coords[self.y_dim].size < 1
#     916 ):
# --> 917     raise NoDataInBounds(
#     918         f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     919     )
#     921 # make sure correct attributes preserved & projection added
#     922 _add_attrs_proj(cropped_ds, self._obj)
#
# NoDataInBounds: No data found in bounds. Data variable: LWDOWN
